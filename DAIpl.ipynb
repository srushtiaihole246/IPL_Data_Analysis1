# %% [markdown]
# ##  Data Analysis of IPL-Matches(2008-2022)
# As you all know Cricket is a sport played and watched by millions of people around the world but Indians are mad about cricket. Cricket is played in our streets. We like it so much. People in india are crazy about the game. Cricket is a Gentlemen Game , As a cricket lover, I decided to analyze the data of IPL matches. Why IPL match? Because cricket is not a game of any specific country or a nation, I love Indian league IPL .So, that why I shall anlyze the data of IPL matches from 2008 to 2022.
#
# I found IPL matches (2008-2022) dataset from kaggle.
# - Here is the link of IPL matches Dataset: https://www.kaggle.com/datasets/vora1011/ipl-2008-to-2021-all-match-dataset?select=IPL_Matches_2008_2022.csv

# %% [markdown]
# ## Data Selection and Installing
# First we will select appropriate dataset from kaggle which I have done. You can check it at this link: https://www.kaggle.com/datasets/vora1011/ipl-2008-to-2021-all-match-dataset?select=IPL_Matches_2008_2022.csv. To download our dataset we have to install opendataset library by pip install command.

# %%
dataset_url = 'https://www.kaggle.com/datasets/vora1011/ipl-2008-to-2021-all-match-dataset?select=IPL_Matches_2008_2022.csv'

# %% [markdown]
# ## Essential Libraries for this Project
# Lets import essential libraries for this project

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# settings

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
import warnings # to ignore warnings so that warnings will not be shown the output
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Data Preparation and Cleaning
# First, we load our dataset into DataFrame and see our DataFrame some first and last rows to overview of dattasets

# %% [markdown]
# # Exploratory Data Analysis
# Now we will analyze our IPL dataset containing information about macthes, venue and scoring of IPL 15 seasons 2008 to 2022.

# %%
df = pd.read_csv("IPL_Matches_2008_2022.csv")

# %%
df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 0              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 1              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 2                         Eden Gardens, Kolkata         Lucknow Super Giants
# 3                         Eden Gardens, Kolkata               Gujarat Titans
# 4                      Wankhede Stadium, Mumbai          Sunrisers Hyderabad
# ..                                          ...                          ...
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision SuperOver                  WinningTeam    WonBy  Margin  \
# 0            bat         N               Gujarat Titans  Wickets     7.0
# 1          field         N             Rajasthan Royals  Wickets     7.0
# 2          field         N  Royal Challengers Bangalore     Runs    14.0
# 3          field         N               Gujarat Titans  Wickets     7.0
# 4            bat         N                 Punjab Kings  Wickets     5.0
# ..           ...       ...                          ...      ...     ...
# 945          bat         N        Kolkata Knight Riders  Wickets     5.0
# 946          bat         N  Royal Challengers Bangalore  Wickets     5.0
# 947          bat         N             Delhi Daredevils  Wickets     9.0
# 948          bat         N          Chennai Super Kings     Runs    33.0
# 949        field         N        Kolkata Knight Riders     Runs   140.0
#
#     method Player_of_Match                                       Team1Players  \
# 0      NaN       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      NaN      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      NaN      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3      NaN       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4      NaN   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
# ..     ...             ...                                                ...
# 945    NaN       DJ Hussey  ['WP Saha', 'BB McCullum', 'RT Ponting', 'SC G...
# 946    NaN      MV Boucher  ['L Ronchi', 'ST Jayasuriya', 'DJ Thornely', '...
# 947    NaN     MF Maharoof  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'MK Tiwa...
# 948    NaN      MEK Hussey  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 949    NaN     BB McCullum  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players        Umpire1  \
# 0    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2    ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4    ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
# ..                                                 ...            ...
# 945  ['AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxma...      BF Bowden
# 946  ['S Chanderpaul', 'R Dravid', 'LRPL Taylor', '...       SJ Davis
# 947  ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...      Aleem Dar
# 948  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...      MR Benson
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...      Asad Rauf
#
#             Umpire2
# 0       Nitin Menon
# 1       Nitin Menon
# 2          MA Gough
# 3         VK Sharma
# 4     NA Patwardhan
# ..              ...
# 945     K Hariharan
# 946       DJ Harper
# 947  GA Pratapkumar
# 948      SL Shastri
# 949     RE Koertzen
#
# [950 rows x 20 columns]

# %%
df.columns
# Out:
# Index(['   ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %% [markdown]
# ## i canot say about mean median and other statistical value >bcoz margin is depanded on wonby col(runs,wicket,superover,noresult)

# %%
df.head
# Out:
# <bound method NDFrame.head of           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 0              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 1              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 2                         Eden Gardens, Kolkata         Lucknow Super Giants
# 3                         Eden Gardens, Kolkata               Gujarat Titans
# 4                      Wankhede Stadium, Mumbai          Sunrisers Hyderabad
# ..                                          ...                          ...
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision SuperOver                  WinningTeam    WonBy  Margin  \
# 0            bat         N               Gujarat Titans  Wickets     7.0
# 1          field         N             Rajasthan Royals  Wickets     7.0
# 2          field         N  Royal Challengers Bangalore     Runs    14.0
# 3          field         N               Gujarat Titans  Wickets     7.0
# 4            bat         N                 Punjab Kings  Wickets     5.0
# ..           ...       ...                          ...      ...     ...
# 945          bat         N        Kolkata Knight Riders  Wickets     5.0
# 946          bat         N  Royal Challengers Bangalore  Wickets     5.0
# 947          bat         N             Delhi Daredevils  Wickets     9.0
# 948          bat         N          Chennai Super Kings     Runs    33.0
# 949        field         N        Kolkata Knight Riders     Runs   140.0
#
#     method Player_of_Match                                       Team1Players  \
# 0      NaN       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      NaN      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      NaN      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3      NaN       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4      NaN   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
# ..     ...             ...                                                ...
# 945    NaN       DJ Hussey  ['WP Saha', 'BB McCullum', 'RT Ponting', 'SC G...
# 946    NaN      MV Boucher  ['L Ronchi', 'ST Jayasuriya', 'DJ Thornely', '...
# 947    NaN     MF Maharoof  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'MK Tiwa...
# 948    NaN      MEK Hussey  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 949    NaN     BB McCullum  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players        Umpire1  \
# 0    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2    ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4    ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
# ..                                                 ...            ...
# 945  ['AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxma...      BF Bowden
# 946  ['S Chanderpaul', 'R Dravid', 'LRPL Taylor', '...       SJ Davis
# 947  ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...      Aleem Dar
# 948  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...      MR Benson
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...      Asad Rauf
#
#             Umpire2
# 0       Nitin Menon
# 1       Nitin Menon
# 2          MA Gough
# 3         VK Sharma
# 4     NA Patwardhan
# ..              ...
# 945     K Hariharan
# 946       DJ Harper
# 947  GA Pratapkumar
# 948      SL Shastri
# 949     RE Koertzen
#
# [950 rows x 20 columns]>

# %%
df['method'].isnull().sum()
# Out:
# np.int64(931)

# %% [markdown]
# By looking at the dataset we can see that our dataset contains many rows and columns. The dataset includes **MatchNumber**, **Team1**, **Team2**, **Venue**, **Team1Players**, **Team2Players**, **Umpire1** and **Umpire2** Data which gives us information about where match held, which teams played a match and about team players, about umpires also and information about **winning team** and win stats.

# %%
df.shape
# Out:
# (950, 20)

# %% [markdown]
#  950 rows and 20 columns in our DatasetThere is

# %%
df.info
# Out:
# <bound method DataFrame.info of           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 0              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 1              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 2                         Eden Gardens, Kolkata         Lucknow Super Giants
# 3                         Eden Gardens, Kolkata               Gujarat Titans
# 4                      Wankhede Stadium, Mumbai          Sunrisers Hyderabad
# ..                                          ...                          ...
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision SuperOver                  WinningTeam    WonBy  Margin  \
# 0            bat         N               Gujarat Titans  Wickets     7.0
# 1          field         N             Rajasthan Royals  Wickets     7.0
# 2          field         N  Royal Challengers Bangalore     Runs    14.0
# 3          field         N               Gujarat Titans  Wickets     7.0
# 4            bat         N                 Punjab Kings  Wickets     5.0
# ..           ...       ...                          ...      ...     ...
# 945          bat         N        Kolkata Knight Riders  Wickets     5.0
# 946          bat         N  Royal Challengers Bangalore  Wickets     5.0
# 947          bat         N             Delhi Daredevils  Wickets     9.0
# 948          bat         N          Chennai Super Kings     Runs    33.0
# 949        field         N        Kolkata Knight Riders     Runs   140.0
#
#     method Player_of_Match                                       Team1Players  \
# 0      NaN       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      NaN      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      NaN      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3      NaN       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4      NaN   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
# ..     ...             ...                                                ...
# 945    NaN       DJ Hussey  ['WP Saha', 'BB McCullum', 'RT Ponting', 'SC G...
# 946    NaN      MV Boucher  ['L Ronchi', 'ST Jayasuriya', 'DJ Thornely', '...
# 947    NaN     MF Maharoof  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'MK Tiwa...
# 948    NaN      MEK Hussey  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 949    NaN     BB McCullum  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players        Umpire1  \
# 0    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2    ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4    ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
# ..                                                 ...            ...
# 945  ['AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxma...      BF Bowden
# 946  ['S Chanderpaul', 'R Dravid', 'LRPL Taylor', '...       SJ Davis
# 947  ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...      Aleem Dar
# 948  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...      MR Benson
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...      Asad Rauf
#
#             Umpire2
# 0       Nitin Menon
# 1       Nitin Menon
# 2          MA Gough
# 3         VK Sharma
# 4     NA Patwardhan
# ..              ...
# 945     K Hariharan
# 946       DJ Harper
# 947  GA Pratapkumar
# 948      SL Shastri
# 949     RE Koertzen
#
# [950 rows x 20 columns]>

# %% [markdown]
# So, we have also some null values and unnecessary columns.

# %%
df.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %% [markdown]
# **In IPL 2008 to 2022 dataset the maximum margin of winning team is 146 runs and the minimum margin is only 1 run.**

# %%
df.nunique()
# Out:
#    ID              950
# City                33
# Date               706
# Season              15
# MatchNumber         80
# Team1               18
# Team2               18
# Venue               49
# TossWinner          18
# TossDecision         2
# SuperOver            2
# WinningTeam         18
# WonBy                4
# Margin              94
# method               1
# Player_of_Match    262
# Team1Players       932
# Team2Players       937
# Umpire1             58
# Umpire2             60
# dtype: int64

# %% [markdown]
# ### The above table provides us with very useful information. By above table we can see that as of 2022, there have been 15 seasons of IPL tournament hosted by 33 cities. Although, 18 teams have played and 262 Players become player of match in past seasons of IPL.

# %%
df.isnull().sum()
# Out:
#    ID                0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(1012)

# %%
print("Total Null Cells",df.isnull().sum().sum())
df.isnull().sum()
# Out:
# Total Null Cells 1012
#    ID                0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
df.isnull().values.any()
# Out:
# np.True_

# %%
df['WonBy'].value_counts()
# Out:
# WonBy
# Wickets      509
# Runs         423
# SuperOver     14
# NoResults      4
# Name: count, dtype: int64

# %%
# groupby
df.groupby('WonBy')['Margin'].median()
# Out:
# WonBy
# NoResults     NaN
# Runs         22.0
# SuperOver     NaN
# Wickets       6.0
# Name: Margin, dtype: float64

# %%
df.groupby('WonBy')['Margin'].std()
# Out:
# WonBy
# NoResults          NaN
# Runs         26.785736
# SuperOver          NaN
# Wickets       1.828664
# Name: Margin, dtype: float64

# %%
df['Umpire1'].dtype
# Out:
# dtype('O')

# %%
df.Date
# Out:
# 0      2022-05-29
# 1      2022-05-27
# 2      2022-05-25
# 3      2022-05-24
# 4      2022-05-22
#           ...
# 945    2008-04-20
# 946    2008-04-20
# 947    2008-04-19
# 948    2008-04-19
# 949    2008-04-18
# Name: Date, Length: 950, dtype: object

# %%
df.Date.dtype
# Out:
# dtype('O')

# %% [markdown]
# In our DataFrame the date should be a string that represent date for future work with date. Let's convert all cells in **Date** column to dates. Pandas have **datetime()** method for this.

# %%
df['Date']=pd.to_datetime(df.Date)
df.Date.head(10)
# Out:
# 0   2022-05-29
# 1   2022-05-27
# 2   2022-05-25
# 3   2022-05-24
# 4   2022-05-22
# 5   2022-05-21
# 6   2022-05-20
# 7   2022-05-19
# 8   2022-05-18
# 9   2022-05-17
# Name: Date, dtype: datetime64[ns]

# %%
df['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['Date'][0]
# Out:
# Timestamp('2022-05-29 00:00:00')

# %%
df['Date'][0].value
# Out:
# 1653782400000000000

# %% [markdown]
# Now, we will clean empty cells, wrong data and unusual data. We will also check any duplicate data in our dataset.

# %%
# cheking duplicates rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# > there are no duplicates within the datasets

# %%
df.columns
# Out:
# Index(['   ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
df.value_counts()
# Out:
#    ID    City           Date        Season   MatchNumber  Team1                        Team2                        Venue                                                TossWinner                   TossDecision  SuperOver  WinningTeam                  WonBy    Margin  method  Player_of_Match   Team1Players                                                                                                                                               Team2Players                                                                                                                                                 Umpire1                Umpire2
# 336022   Delhi          2008-05-17  2007/08  40           Delhi Daredevils             Kings XI Punjab              Feroz Shah Kotla                                     Delhi Daredevils             bat           N          Kings XI Punjab              Runs     6.0     D/L     DPMD Jayawardene  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'TM Dilshan', 'MF Maharoof', 'Shoaib Malik', 'PJ Sangwan', 'KD Karthik', 'A Mishra', 'R Bhatia', 'GD McGrath']       ['SE Marsh', 'JR Hopes', 'Yuvraj Singh', 'LA Pomersbach', 'DPMD Jayawardene', 'IK Pathan', 'RR Powar', 'PP Chawla', 'U Kaul', 'S Sreesanth', 'VRV Singh']    AV Jayaprakash         RE Koertzen        1
# 336025   Kolkata        2008-05-18  2007/08  41           Kolkata Knight Riders        Chennai Super Kings          Eden Gardens                                         Kolkata Knight Riders        bat           N          Chennai Super Kings          Runs     3.0     D/L     M Ntini           ['Salman Butt', 'Mohammad Hafeez', 'SC Ganguly', 'DB Das', 'DJ Hussey', 'LR Shukla', 'WP Saha', 'AB Agarkar', 'I Sharma', 'AB Dinda', 'Shoaib Akhtar']     ['PA Patel', 'SP Fleming', 'S Vidyut', 'SK Raina', 'S Badrinath', 'MS Dhoni', 'JA Morkel', 'MS Gony', 'L Balaji', 'M Muralitharan', 'M Ntini']               Asad Rauf              K Hariharan        1
# 392183   Cape Town      2009-04-19  2009     3            Delhi Daredevils             Kings XI Punjab              Newlands                                             Delhi Daredevils             field         N          Delhi Daredevils             Wickets  10.0    D/L     DL Vettori        ['G Gambhir', 'V Sehwag', 'TM Dilshan', 'AB de Villiers', 'MK Tiwary', 'KD Karthik', 'DP Nannes', 'DL Vettori', 'VY Mahesh', 'AM Salvi', 'PJ Sangwan']     ['RS Bopara', 'K Goel', 'Yuvraj Singh', 'KC Sangakkara', 'DPMD Jayawardene', 'IK Pathan', 'PP Chawla', 'T Kohli', 'VS Malik', 'VRV Singh', 'YA Abdulla']     MR Benson              SD Ranade          1
# 392186   Durban         2009-04-21  2009     6            Kings XI Punjab              Kolkata Knight Riders        Kingsmead                                            Kolkata Knight Riders        field         N          Kolkata Knight Riders        Runs     11.0    D/L     CH Gayle          ['RS Bopara', 'K Goel', 'IK Pathan', 'KC Sangakkara', 'Yuvraj Singh', 'DPMD Jayawardene', 'T Kohli', 'PP Chawla', 'VS Malik', 'VRV Singh', 'YA Abdulla']   ['BB McCullum', 'CH Gayle', 'BJ Hodge', 'SC Ganguly', 'Yashpal Singh', 'A Chopra', 'MC Henriques', 'LR Shukla', 'I Sharma', 'M Kartik', 'AB Dinda']          DJ Harper              SD Ranade          1
# 392214   Centurion      2009-05-07  2009     34           Chennai Super Kings          Kings XI Punjab              SuperSport Park                                      Chennai Super Kings          bat           N          Chennai Super Kings          Runs     12.0    D/L     ML Hayden         ['S Badrinath', 'ML Hayden', 'SK Raina', 'MS Dhoni', 'JA Morkel', 'GJ Bailey', 'S Tyagi', 'SB Jakati', 'L Balaji', 'M Muralitharan', 'MS Gony']            ['S Sohal', 'SM Katich', 'K Goel', 'Yuvraj Singh', 'DPMD Jayawardene', 'KC Sangakkara', 'IK Pathan', 'S Sreesanth', 'PP Chawla', 'YA Abdulla', 'VRV Singh']  DJ Harper              TH Wijewardene     1
# 501215   Kochi          2011-04-18  2011     18           Kochi Tuskers Kerala         Chennai Super Kings          Nehru Stadium                                        Kochi Tuskers Kerala         field         N          Kochi Tuskers Kerala         Wickets  7.0     D/L     BB McCullum       ['BB McCullum', 'DPMD Jayawardene', 'PA Patel', 'BJ Hodge', 'RA Jadeja', 'KM Jadhav', 'NLTC Perera', 'RV Gomez', 'R Vinay Kumar', 'RP Singh', 'RR Powar']  ['MEK Hussey', 'M Vijay', 'SK Raina', 'S Badrinath', 'MS Dhoni', 'JA Morkel', 'S Anirudha', 'R Ashwin', 'SB Jakati', 'TG Southee', 'DE Bollinger']           K Hariharan            AL Hill            1
# 501245   Kolkata        2011-05-07  2011     48           Kolkata Knight Riders        Chennai Super Kings          Eden Gardens                                         Chennai Super Kings          bat           N          Kolkata Knight Riders        Runs     10.0    D/L     Iqbal Abdulla     ['EJG Morgan', 'JH Kallis', 'G Gambhir', 'MK Tiwary', 'YK Pathan', 'MV Boucher', 'R Bhatia', 'Iqbal Abdulla', 'B Lee', 'L Balaji', 'JD Unadkat']           ['MEK Hussey', 'M Vijay', 'SK Raina', 'S Badrinath', 'JA Morkel', 'MS Dhoni', 'WP Saha', 'R Ashwin', 'DE Bollinger', 'SB Jakati', 'S Randiv']                Asad Rauf              PR Reiffel         1
# 501255   Bangalore      2011-05-14  2011     58           Royal Challengers Bangalore  Kolkata Knight Riders        M Chinnaswamy Stadium                                Royal Challengers Bangalore  field         N          Royal Challengers Bangalore  Wickets  4.0     D/L     CH Gayle          ['CH Gayle', 'LA Pomersbach', 'V Kohli', 'AB de Villiers', 'M Kaif', 'KB Arun Karthik', 'SS Tiwary', 'A Mithun', 'Z Khan', 'S Aravind', 'CK Langeveldt']   ['JH Kallis', 'EJG Morgan', 'G Gambhir', 'MK Tiwary', 'YK Pathan', 'MV Boucher', 'R Bhatia', 'Iqbal Abdulla', 'B Lee', 'L Balaji', 'JD Unadkat']             RE Koertzen            RB Tiffin          1
# 733993   Delhi          2014-05-10  2014     32           Delhi Daredevils             Sunrisers Hyderabad          Feroz Shah Kotla                                     Sunrisers Hyderabad          field         N          Sunrisers Hyderabad          Wickets  8.0     D/L     DW Steyn          ['Q de Kock', 'KP Pietersen', 'MA Agarwal', 'KD Karthik', 'LR Shukla', 'JP Duminy', 'KM Jadhav', 'R Shukla', 'Mohammed Shami', 'Imran Tahir', 'S Kaul']    ['AJ Finch', 'S Dhawan', 'DA Warner', 'NV Ojha', 'KL Rahul', 'MC Henriques', 'IK Pathan', 'KV Sharma', 'DW Steyn', 'A Mishra', 'B Kumar']                    RM Deshpande           BNJ Oxenford       1
# 829743   Visakhapatnam  2015-04-22  2015     19           Sunrisers Hyderabad          Kolkata Knight Riders        Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium  Kolkata Knight Riders        field         N          Sunrisers Hyderabad          Runs     16.0    D/L     DA Warner         ['S Dhawan', 'DA Warner', 'RS Bopara', 'NV Ojha', 'MC Henriques', 'KL Rahul', 'KV Sharma', 'Bipul Sharma', 'P Kumar', 'B Kumar', 'DW Steyn']               ['RV Uthappa', 'G Gambhir', 'MK Pandey', 'AD Russell', 'YK Pathan', 'SA Yadav', 'J Botha', 'PP Chawla', 'SP Narine', 'M Morkel', 'UT Yadav']                 RK Illingworth         VA Kulkarni        1
# 829807   Hyderabad      2015-05-15  2015     52           Sunrisers Hyderabad          Royal Challengers Bangalore  Rajiv Gandhi International Stadium, Uppal            Sunrisers Hyderabad          bat           N          Royal Challengers Bangalore  Wickets  6.0     D/L     V Kohli           ['DA Warner', 'S Dhawan', 'MC Henriques', 'EJG Morgan', 'NV Ojha', 'KL Rahul', 'Bipul Sharma', 'KV Sharma', 'B Kumar', 'P Kumar', 'DW Steyn']              ['CH Gayle', 'V Kohli', 'AB de Villiers', 'Mandeep Singh', 'KD Karthik', 'SN Khan', 'D Wiese', 'MA Starc', 'HV Patel', 'YS Chahal', 'AB Dinda']              AK Chaudhary           HDPK Dharmasena    1
# 980943   Hyderabad      2016-04-26  2016     22           Sunrisers Hyderabad          Rising Pune Supergiants      Rajiv Gandhi International Stadium, Uppal            Rising Pune Supergiants      field         N          Rising Pune Supergiants      Runs     34.0    D/L     AB Dinda          ['DA Warner', 'S Dhawan', 'AP Tare', 'EJG Morgan', 'DJ Hooda', 'MC Henriques', 'NV Ojha', 'Bipul Sharma', 'B Kumar', 'A Nehra', 'Mustafizur Rahman']       ['AM Rahane', 'F du Plessis', 'SPD Smith', 'MS Dhoni', 'SS Tiwary', 'NLTC Perera', 'MR Marsh', 'R Bhatia', 'R Ashwin', 'M Ashwin', 'AB Dinda']               AY Dandekar            CK Nandan          1
# 980989   Kolkata        2016-05-14  2016     45           Kolkata Knight Riders        Rising Pune Supergiants      Eden Gardens                                         Rising Pune Supergiants      bat           N          Kolkata Knight Riders        Wickets  8.0     D/L     YK Pathan         ['RV Uthappa', 'G Gambhir', 'MK Pandey', 'YK Pathan', 'Shakib Al Hasan', 'SA Yadav', 'AD Russell', 'PP Chawla', 'SP Narine', 'AS Rajpoot', 'M Morkel']     ['AM Rahane', 'UT Khawaja', 'GJ Bailey', 'SS Tiwary', 'IK Pathan', 'MS Dhoni', 'NLTC Perera', 'R Ashwin', 'A Zampa', 'M Ashwin', 'AB Dinda']                 A Nand Kishore         BNJ Oxenford       1
# 980997   Visakhapatnam  2016-05-17  2016     49           Rising Pune Supergiants      Delhi Daredevils             Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium  Rising Pune Supergiants      field         N          Rising Pune Supergiants      Runs     19.0    D/L     AB Dinda          ['AM Rahane', 'UT Khawaja', 'GJ Bailey', 'SS Tiwary', 'IK Pathan', 'MS Dhoni', 'NLTC Perera', 'R Ashwin', 'A Zampa', 'AB Dinda', 'DL Chahar']              ['Q de Kock', 'SS Iyer', 'KK Nair', 'SV Samson', 'RR Pant', 'JP Duminy', 'CH Morris', 'NM Coulter-Nile', 'A Mishra', 'Z Khan', 'Mohammed Shami']             Nitin Menon            C Shamshuddin      1
# 980999   Bangalore      2016-05-18  2016     50           Royal Challengers Bangalore  Kings XI Punjab              M Chinnaswamy Stadium                                Kings XI Punjab              field         N          Royal Challengers Bangalore  Runs     82.0    D/L     V Kohli           ['CH Gayle', 'V Kohli', 'AB de Villiers', 'KL Rahul', 'SR Watson', 'Sachin Baby', 'STR Binny', 'CJ Jordan', 'S Aravind', 'VR Aaron', 'YS Chahal']          ['M Vijay', 'HM Amla', 'WP Saha', 'DA Miller', 'Gurkeerat Singh', 'AR Patel', 'F Behardien', 'KJ Abbott', 'MM Sharma', 'KC Cariappa', 'Sandeep Sharma']      KN Ananthapadmanabhan  M Erasmus          1
# 1082648  Bangalore      2017-05-17  2017     Eliminator   Sunrisers Hyderabad          Kolkata Knight Riders        M Chinnaswamy Stadium                                Kolkata Knight Riders        field         N          Kolkata Knight Riders        Wickets  7.0     D/L     NM Coulter-Nile   ['DA Warner', 'S Dhawan', 'KS Williamson', 'Yuvraj Singh', 'V Shankar', 'NV Ojha', 'CJ Jordan', 'Bipul Sharma', 'B Kumar', 'Rashid Khan', 'S Kaul']        ['RV Uthappa', 'CA Lynn', 'YK Pathan', 'G Gambhir', 'IR Jaggi', 'SA Yadav', 'SP Narine', 'PP Chawla', 'UT Yadav', 'NM Coulter-Nile', 'TA Boult']             AK Chaudhary           Nitin Menon        1
# 1136566  Jaipur         2018-04-11  2018     6            Rajasthan Royals             Delhi Daredevils             Sawai Mansingh Stadium                               Delhi Daredevils             field         N          Rajasthan Royals             Runs     10.0    D/L     SV Samson         ['AM Rahane', 'DJM Short', 'BA Stokes', 'SV Samson', 'JC Buttler', 'RA Tripathi', 'K Gowtham', 'S Gopal', 'DS Kulkarni', 'JD Unadkat', 'B Laughlin']       ['GJ Maxwell', 'C Munro', 'RR Pant', 'CH Morris', 'V Shankar', 'SS Iyer', 'G Gambhir', 'R Tewatia', 'S Nadeem', 'TA Boult', 'Mohammed Shami']                KN Ananthapadmanabhan  Nitin Menon        1
# 1136578  Kolkata        2018-04-21  2018     18           Kolkata Knight Riders        Kings XI Punjab              Eden Gardens                                         Kings XI Punjab              field         N          Kings XI Punjab              Wickets  9.0     D/L     KL Rahul          ['CA Lynn', 'SP Narine', 'RV Uthappa', 'N Rana', 'KD Karthik', 'AD Russell', 'Shubman Gill', 'TK Curran', 'PP Chawla', 'Shivam Mavi', 'Kuldeep Yadav']     ['KL Rahul', 'CH Gayle', 'MA Agarwal', 'KK Nair', 'AJ Finch', 'Yuvraj Singh', 'R Ashwin', 'AJ Tye', 'BB Sran', 'Mujeeb Ur Rahman', 'AS Rajpoot']             A Deshmukh             C Shamshuddin      1
# 1136592  Delhi          2018-05-02  2018     32           Delhi Daredevils             Rajasthan Royals             Arun Jaitley Stadium                                 Rajasthan Royals             field         N          Delhi Daredevils             Runs     4.0     D/L     RR Pant           ['PP Shaw', 'C Munro', 'SS Iyer', 'RR Pant', 'GJ Maxwell', 'V Shankar', 'LE Plunkett', 'A Mishra', 'S Nadeem', 'Avesh Khan', 'TA Boult']                   ['DJM Short', 'JC Buttler', 'SV Samson', 'BA Stokes', 'RA Tripathi', 'K Gowtham', 'JC Archer', 'AM Rahane', 'JD Unadkat', 'DS Kulkarni', 'S Gopal']          CK Nandan              VK Sharma          1
# Name: count, dtype: int64

# %%
df['City'].value_counts()
# Out:
# City
# Mumbai            159
# Kolkata            79
# Delhi              78
# Chennai            67
# Bangalore          65
# Hyderabad          64
# Chandigarh         56
# Pune               51
# Jaipur             47
# Abu Dhabi          37
# Ahmedabad          19
# Bengaluru          15
# Durban             15
# Visakhapatnam      13
# Dubai              13
# Centurion          12
# Sharjah            10
# Rajkot             10
# Navi Mumbai         9
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Port Elizabeth      7
# Cuttack             7
# Ranchi              7
# Cape Town           7
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
len(df['City'].value_counts())
# Out:
# 33

# %%
(df['City'].value_counts().head(33))
# Out:
# City
# Mumbai            159
# Kolkata            79
# Delhi              78
# Chennai            67
# Bangalore          65
# Hyderabad          64
# Chandigarh         56
# Pune               51
# Jaipur             47
# Abu Dhabi          37
# Ahmedabad          19
# Bengaluru          15
# Durban             15
# Visakhapatnam      13
# Dubai              13
# Centurion          12
# Sharjah            10
# Rajkot             10
# Navi Mumbai         9
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Port Elizabeth      7
# Cuttack             7
# Ranchi              7
# Cape Town           7
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
for city in df['City'].value_counts().index:
    print(city)
# Out:
# Mumbai
# Kolkata
# Delhi
# Chennai
# Bangalore
# Hyderabad
# Chandigarh
# Pune
# Jaipur
# Abu Dhabi
# Ahmedabad
# Bengaluru
# Durban
# Visakhapatnam
# Dubai
# Centurion
# Sharjah
# Rajkot
# Navi Mumbai
# Indore
# Dharamsala
# Johannesburg
# Port Elizabeth
# Cuttack
# Ranchi
# Cape Town
# Raipur
# Kochi
# Kanpur
# Nagpur
# Kimberley
# East London
# Bloemfontein

# %%
df['City'].value_counts().sort_index()
# Out:
# City
# Abu Dhabi          37
# Ahmedabad          19
# Bangalore          65
# Bengaluru          15
# Bloemfontein        2
# Cape Town           7
# Centurion          12
# Chandigarh         56
# Chennai            67
# Cuttack             7
# Delhi              78
# Dharamsala          9
# Dubai              13
# Durban             15
# East London         3
# Hyderabad          64
# Indore              9
# Jaipur             47
# Johannesburg        8
# Kanpur              4
# Kimberley           3
# Kochi               5
# Kolkata            79
# Mumbai            159
# Nagpur              3
# Navi Mumbai         9
# Port Elizabeth      7
# Pune               51
# Raipur              6
# Rajkot             10
# Ranchi              7
# Sharjah            10
# Visakhapatnam      13
# Name: count, dtype: int64

# %%
df['City'].replace
# Out:
# <bound method NDFrame.replace of 0       Ahmedabad
# 1       Ahmedabad
# 2         Kolkata
# 3         Kolkata
# 4          Mumbai
#           ...
# 945       Kolkata
# 946        Mumbai
# 947         Delhi
# 948    Chandigarh
# 949     Bangalore
# Name: City, Length: 950, dtype: object>

# %%
f1=df['City'] == 'Bengaluru'

# %%
len(df[f1])
# Out:
# 15

# %%
df[f1].replace('')
# Out:
#           ID       City       Date Season MatchNumber  \
# 200  1178429  Bengaluru 2019-05-04   2019          54
# 205  1178424  Bengaluru 2019-04-30   2019          49
# 212  1178417  Bengaluru 2019-04-24   2019          42
# 216  1178414  Bengaluru 2019-04-21   2019          39
# 234  1178395  Bengaluru 2019-04-07   2019          20
# 237  1175372  Bengaluru 2019-04-05   2019          17
# 247  1175362  Bengaluru 2019-03-28   2019           7
# 263  1136611  Bengaluru 2018-05-17   2018          51
# 283  1136591  Bengaluru 2018-05-01   2018          31
# 286  1136589  Bengaluru 2018-04-29   2018          29
# 290  1136584  Bengaluru 2018-04-25   2018          24
# 295  1136579  Bengaluru 2018-04-21   2018          19
# 303  1136571  Bengaluru 2018-04-15   2018          11
# 306  1136568  Bengaluru 2018-04-13   2018           8
# 368  1082595  Bengaluru 2017-04-08   2017           5
#
#                            Team1                        Team2  \
# 200          Sunrisers Hyderabad  Royal Challengers Bangalore
# 205  Royal Challengers Bangalore             Rajasthan Royals
# 212  Royal Challengers Bangalore              Kings XI Punjab
# 216  Royal Challengers Bangalore          Chennai Super Kings
# 234  Royal Challengers Bangalore               Delhi Capitals
# 237  Royal Challengers Bangalore        Kolkata Knight Riders
# 247               Mumbai Indians  Royal Challengers Bangalore
# 263  Royal Challengers Bangalore          Sunrisers Hyderabad
# 283  Royal Challengers Bangalore               Mumbai Indians
# 286  Royal Challengers Bangalore        Kolkata Knight Riders
# 290  Royal Challengers Bangalore          Chennai Super Kings
# 295             Delhi Daredevils  Royal Challengers Bangalore
# 303             Rajasthan Royals  Royal Challengers Bangalore
# 306              Kings XI Punjab  Royal Challengers Bangalore
# 368  Royal Challengers Bangalore             Delhi Daredevils
#
#                      Venue                   TossWinner TossDecision  \
# 200  M.Chinnaswamy Stadium  Royal Challengers Bangalore        field
# 205  M.Chinnaswamy Stadium             Rajasthan Royals        field
# 212  M.Chinnaswamy Stadium              Kings XI Punjab        field
# 216  M.Chinnaswamy Stadium          Chennai Super Kings        field
# 234  M.Chinnaswamy Stadium               Delhi Capitals        field
# 237  M.Chinnaswamy Stadium        Kolkata Knight Riders        field
# 247  M.Chinnaswamy Stadium  Royal Challengers Bangalore        field
# 263  M.Chinnaswamy Stadium          Sunrisers Hyderabad        field
# 283  M.Chinnaswamy Stadium               Mumbai Indians        field
# 286  M.Chinnaswamy Stadium        Kolkata Knight Riders        field
# 290  M.Chinnaswamy Stadium          Chennai Super Kings        field
# 295  M.Chinnaswamy Stadium  Royal Challengers Bangalore        field
# 303  M.Chinnaswamy Stadium  Royal Challengers Bangalore        field
# 306  M.Chinnaswamy Stadium  Royal Challengers Bangalore        field
# 368  M.Chinnaswamy Stadium  Royal Challengers Bangalore          bat
#
#     SuperOver                  WinningTeam      WonBy  Margin method  \
# 200         N  Royal Challengers Bangalore    Wickets     4.0    NaN
# 205       NaN                          NaN  NoResults     NaN    NaN
# 212         N  Royal Challengers Bangalore       Runs    17.0    NaN
# 216         N  Royal Challengers Bangalore       Runs     1.0    NaN
# 234         N               Delhi Capitals    Wickets     4.0    NaN
# 237         N        Kolkata Knight Riders    Wickets     5.0    NaN
# 247         N               Mumbai Indians       Runs     6.0    NaN
# 263         N  Royal Challengers Bangalore       Runs    14.0    NaN
# 283         N  Royal Challengers Bangalore       Runs    14.0    NaN
# 286         N        Kolkata Knight Riders    Wickets     6.0    NaN
# 290         N          Chennai Super Kings    Wickets     5.0    NaN
# 295         N  Royal Challengers Bangalore    Wickets     6.0    NaN
# 303         N             Rajasthan Royals       Runs    19.0    NaN
# 306         N  Royal Challengers Bangalore    Wickets     4.0    NaN
# 368         N  Royal Challengers Bangalore       Runs    15.0    NaN
#
#     Player_of_Match                                       Team1Players  \
# 200      SO Hetmyer  ['WP Saha', 'MJ Guptill', 'MK Pandey', 'KS Wil...
# 205             NaN  ['V Kohli', 'AB de Villiers', 'MP Stoinis', 'H...
# 212  AB de Villiers  ['PA Patel', 'V Kohli', 'AB de Villiers', 'MM ...
# 216        PA Patel  ['PA Patel', 'V Kohli', 'AB de Villiers', 'AD ...
# 234        K Rabada  ['PA Patel', 'V Kohli', 'AB de Villiers', 'MP ...
# 237      AD Russell  ['PA Patel', 'V Kohli', 'AB de Villiers', 'MP ...
# 247       JJ Bumrah  ['Q de Kock', 'RG Sharma', 'SA Yadav', 'Yuvraj...
# 263  AB de Villiers  ['PA Patel', 'V Kohli', 'AB de Villiers', 'MM ...
# 283      TG Southee  ['M Vohra', 'Q de Kock', 'BB McCullum', 'V Koh...
# 286         CA Lynn  ['Q de Kock', 'BB McCullum', 'V Kohli', 'M Voh...
# 290        MS Dhoni  ['Q de Kock', 'V Kohli', 'AB de Villiers', 'CJ...
# 295  AB de Villiers  ['JJ Roy', 'G Gambhir', 'SS Iyer', 'RR Pant', ...
# 303       SV Samson  ['AM Rahane', 'DJM Short', 'SV Samson', 'BA St...
# 306        UT Yadav  ['KL Rahul', 'MA Agarwal', 'AJ Finch', 'Yuvraj...
# 368       KM Jadhav  ['CH Gayle', 'SR Watson', 'Mandeep Singh', 'KM...
#
#                                           Team2Players        Umpire1  \
# 200  ['PA Patel', 'V Kohli', 'AB de Villiers', 'SO ...   AK Chaudhary
# 205  ['SV Samson', 'LS Livingstone', 'AM Rahane', '...       NJ Llong
# 212  ['KL Rahul', 'CH Gayle', 'MA Agarwal', 'DA Mil...   BNJ Oxenford
# 216  ['SR Watson', 'F du Plessis', 'SK Raina', 'AT ...      RJ Tucker
# 234  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'CA Ingram'...         S Ravi
# 237  ['CA Lynn', 'SP Narine', 'RV Uthappa', 'N Rana...   AK Chaudhary
# 247  ['PA Patel', 'MM Ali', 'V Kohli', 'AB de Villi...      CK Nandan
# 263  ['S Dhawan', 'AD Hales', 'KS Williamson', 'MK ...    AY Dandekar
# 283  ['SA Yadav', 'Ishan Kishan', 'JP Duminy', 'RG ...      M Erasmus
# 286  ['CA Lynn', 'SP Narine', 'RV Uthappa', 'N Rana...   AK Chaudhary
# 290  ['SR Watson', 'AT Rayudu', 'SK Raina', 'SW Bil...       NJ Llong
# 295  ['Q de Kock', 'M Vohra', 'V Kohli', 'AB de Vil...    CB Gaffaney
# 303  ['BB McCullum', 'Q de Kock', 'V Kohli', 'AB de...  C Shamshuddin
# 306  ['Q de Kock', 'BB McCullum', 'V Kohli', 'AB de...     A Deshmukh
# 368  ['AP Tare', 'SW Billings', 'KK Nair', 'SV Sams...         S Ravi
#
#            Umpire2
# 200       NJ Llong
# 205      UV Gandhe
# 212  C Shamshuddin
# 216    VA Kulkarni
# 234       YC Barde
# 237    CB Gaffaney
# 247         S Ravi
# 263         S Ravi
# 283    Nitin Menon
# 286       NJ Llong
# 290      VK Sharma
# 295      CK Nandan
# 303         S Ravi
# 306         S Ravi
# 368      VK Sharma

# %%
df['City']=df['City'].replace('Bengaluru','Bangalore')

# %%
df['City'].value_counts().sort_index()
# Out:
# City
# Abu Dhabi          37
# Ahmedabad          19
# Bangalore          80
# Bloemfontein        2
# Cape Town           7
# Centurion          12
# Chandigarh         56
# Chennai            67
# Cuttack             7
# Delhi              78
# Dharamsala          9
# Dubai              13
# Durban             15
# East London         3
# Hyderabad          64
# Indore              9
# Jaipur             47
# Johannesburg        8
# Kanpur              4
# Kimberley           3
# Kochi               5
# Kolkata            79
# Mumbai            159
# Nagpur              3
# Navi Mumbai         9
# Port Elizabeth      7
# Pune               51
# Raipur              6
# Rajkot             10
# Ranchi              7
# Sharjah            10
# Visakhapatnam      13
# Name: count, dtype: int64

# %%
df['Team1'].value_counts()
# Out:
# Team1
# Royal Challengers Bangalore    126
# Mumbai Indians                 112
# Chennai Super Kings            111
# Kolkata Knight Riders          105
# Kings XI Punjab                 92
# Rajasthan Royals                89
# Delhi Daredevils                85
# Sunrisers Hyderabad             69
# Deccan Chargers                 39
# Delhi Capitals                  29
# Pune Warriors                   23
# Punjab Kings                    18
# Gujarat Lions                   16
# Lucknow Super Giants             8
# Gujarat Titans                   7
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %%
df['Team1']=df['Team1'].str.replace('Kings XI Punjab','Punjab Kings')
df['Team2']=df['Team2'].str.replace('Kings XI Punjab','Punjab Kings')
df['WinningTeam']=df['WinningTeam'].str.replace('Kings XI Punjab','Punjab Kings')

# %%
df['Team1']=df['Team1'].replace('Kings XI Punjab','Punjab Kings')

# %%
df['Team2']=df['Team2'].replace('Kings XI Punjab','Punjab Kings')

# %%
df['WinningTeam']=df['WinningTeam'].replace('Kings XI Punjab','Punjab Kings')

# %%
df['WinningTeam'].value_counts()
# Out:
# WinningTeam
# Mumbai Indians                 131
# Chennai Super Kings            121
# Kolkata Knight Riders          114
# Royal Challengers Bangalore    109
# Punjab Kings                   101
# Rajasthan Royals                96
# Sunrisers Hyderabad             75
# Delhi Daredevils                67
# Delhi Capitals                  36
# Deccan Chargers                 29
# Gujarat Lions                   13
# Gujarat Titans                  12
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Lucknow Super Giants             9
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['   ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
df['Team2'].value_counts()
# Out:
# Team2
# Mumbai Indians                 119
# Kolkata Knight Riders          118
# Punjab Kings                   108
# Rajasthan Royals               103
# Royal Challengers Bangalore    100
# Chennai Super Kings             97
# Sunrisers Hyderabad             83
# Delhi Daredevils                76
# Deccan Chargers                 36
# Delhi Capitals                  34
# Pune Warriors                   23
# Gujarat Lions                   14
# Gujarat Titans                   9
# Rising Pune Supergiant           9
# Lucknow Super Giants             7
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %%
df['Team1']=df['Team1'].str.replace('Delhi Daredevils','Delhi Capitals')
df['Team2']=df['Team2'].str.replace('Delhi Daredevils','Delhi Capitals')
df['WinningTeam']=df['WinningTeam'].str.replace('Delhi Daredevils','Delhi Capitals')

# %%
df['Team1']=df['Team1'].str.replace('Rising Pune Supergiants','Rising Pune Supergiant')
df['Team2']=df['Team2'].str.replace('Rising Pune Supergiants','Rising Pune Supergiant')
df['WinningTeam']=df['WinningTeam'].str.replace('Rising Pune Supergiants','Rising Pune Supergiant')

# %%
df['TossWinner']=df['TossWinner'].replace('Kings XI Punjab','Punjab Kings')

# %% [markdown]
# ## dealing with null values

# %%
df.isnull().sum()
# Out:
#    ID                0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
# city
c1 = df['City'].isnull()
df[c1]
# Out:
#           ID City       Date   Season  MatchNumber  \
# 134  1237181  NaN 2020-11-10  2020/21        Final
# 137  1237177  NaN 2020-11-05  2020/21  Qualifier 1
# 138  1216495  NaN 2020-11-03  2020/21           56
# 140  1216530  NaN 2020-11-01  2020/21           54
# 142  1216535  NaN 2020-10-31  2020/21           51
# 143  1216502  NaN 2020-10-31  2020/21           52
# 145  1216536  NaN 2020-10-29  2020/21           49
# 147  1216524  NaN 2020-10-27  2020/21           47
# 148  1216520  NaN 2020-10-26  2020/21           46
# 150  1216544  NaN 2020-10-25  2020/21           44
# 151  1216498  NaN 2020-10-24  2020/21           43
# 153  1216521  NaN 2020-10-23  2020/21           41
# 154  1216518  NaN 2020-10-22  2020/21           40
# 156  1216546  NaN 2020-10-20  2020/21           38
# 159  1216517  NaN 2020-10-18  2020/21           36
# 160  1216522  NaN 2020-10-17  2020/21           33
# 161  1216509  NaN 2020-10-17  2020/21           34
# 163  1216531  NaN 2020-10-15  2020/21           31
# 164  1216543  NaN 2020-10-14  2020/21           30
# 165  1216528  NaN 2020-10-13  2020/21           29
# 166  1216540  NaN 2020-10-12  2020/21           28
# 167  1216507  NaN 2020-10-11  2020/21           26
# 170  1216525  NaN 2020-10-10  2020/21           25
# 171  1216500  NaN 2020-10-09  2020/21           23
# 172  1216542  NaN 2020-10-08  2020/21           22
# 175  1216519  NaN 2020-10-05  2020/21           19
# 176  1216513  NaN 2020-10-04  2020/21           18
# 177  1216538  NaN 2020-10-04  2020/21           17
# 179  1216515  NaN 2020-10-03  2020/21           16
# 180  1216516  NaN 2020-10-02  2020/21           14
# 182  1216504  NaN 2020-09-30  2020/21           12
# 184  1216547  NaN 2020-09-28  2020/21           10
# 185  1216527  NaN 2020-09-27  2020/21            9
# 187  1216539  NaN 2020-09-25  2020/21            7
# 188  1216510  NaN 2020-09-24  2020/21            6
# 190  1216496  NaN 2020-09-22  2020/21            4
# 191  1216534  NaN 2020-09-21  2020/21            3
# 192  1216493  NaN 2020-09-20  2020/21            2
# 532   729317  NaN 2014-04-30     2014           20
# 534   729313  NaN 2014-04-28     2014           18
# 535   729311  NaN 2014-04-27     2014           17
# 536   729309  NaN 2014-04-27     2014           16
# 539   729301  NaN 2014-04-25     2014           12
# 540   729303  NaN 2014-04-25     2014           13
# 541   729299  NaN 2014-04-24     2014           11
# 542   729297  NaN 2014-04-23     2014           10
# 543   729295  NaN 2014-04-22     2014            9
# 545   729291  NaN 2014-04-20     2014            7
# 546   729289  NaN 2014-04-19     2014            6
# 547   729287  NaN 2014-04-19     2014            5
# 550   729281  NaN 2014-04-17     2014            2
#
#                            Team1                        Team2  \
# 134               Delhi Capitals               Mumbai Indians
# 137               Mumbai Indians               Delhi Capitals
# 138               Mumbai Indians          Sunrisers Hyderabad
# 140        Kolkata Knight Riders             Rajasthan Royals
# 142               Delhi Capitals               Mumbai Indians
# 143  Royal Challengers Bangalore          Sunrisers Hyderabad
# 145        Kolkata Knight Riders          Chennai Super Kings
# 147          Sunrisers Hyderabad               Delhi Capitals
# 148        Kolkata Knight Riders                 Punjab Kings
# 150  Royal Challengers Bangalore          Chennai Super Kings
# 151                 Punjab Kings          Sunrisers Hyderabad
# 153          Chennai Super Kings               Mumbai Indians
# 154             Rajasthan Royals          Sunrisers Hyderabad
# 156               Delhi Capitals                 Punjab Kings
# 159               Mumbai Indians                 Punjab Kings
# 160             Rajasthan Royals  Royal Challengers Bangalore
# 161          Chennai Super Kings               Delhi Capitals
# 163  Royal Challengers Bangalore                 Punjab Kings
# 164               Delhi Capitals             Rajasthan Royals
# 165          Chennai Super Kings          Sunrisers Hyderabad
# 166  Royal Challengers Bangalore        Kolkata Knight Riders
# 167          Sunrisers Hyderabad             Rajasthan Royals
# 170  Royal Challengers Bangalore          Chennai Super Kings
# 171               Delhi Capitals             Rajasthan Royals
# 172          Sunrisers Hyderabad                 Punjab Kings
# 175               Delhi Capitals  Royal Challengers Bangalore
# 176                 Punjab Kings          Chennai Super Kings
# 177               Mumbai Indians          Sunrisers Hyderabad
# 179               Delhi Capitals        Kolkata Knight Riders
# 180          Sunrisers Hyderabad          Chennai Super Kings
# 182        Kolkata Knight Riders             Rajasthan Royals
# 184  Royal Challengers Bangalore               Mumbai Indians
# 185                 Punjab Kings             Rajasthan Royals
# 187               Delhi Capitals          Chennai Super Kings
# 188                 Punjab Kings  Royal Challengers Bangalore
# 190             Rajasthan Royals          Chennai Super Kings
# 191  Royal Challengers Bangalore          Sunrisers Hyderabad
# 192               Delhi Capitals                 Punjab Kings
# 532               Mumbai Indians          Sunrisers Hyderabad
# 534                 Punjab Kings  Royal Challengers Bangalore
# 535          Sunrisers Hyderabad          Chennai Super Kings
# 536               Delhi Capitals               Mumbai Indians
# 539          Sunrisers Hyderabad               Delhi Capitals
# 540          Chennai Super Kings               Mumbai Indians
# 541  Royal Challengers Bangalore        Kolkata Knight Riders
# 542             Rajasthan Royals          Chennai Super Kings
# 543                 Punjab Kings          Sunrisers Hyderabad
# 545             Rajasthan Royals                 Punjab Kings
# 546        Kolkata Knight Riders               Delhi Capitals
# 547  Royal Challengers Bangalore               Mumbai Indians
# 550               Delhi Capitals  Royal Challengers Bangalore
#
#                                    Venue                   TossWinner  \
# 134  Dubai International Cricket Stadium               Delhi Capitals
# 137  Dubai International Cricket Stadium               Delhi Capitals
# 138              Sharjah Cricket Stadium          Sunrisers Hyderabad
# 140  Dubai International Cricket Stadium             Rajasthan Royals
# 142  Dubai International Cricket Stadium               Mumbai Indians
# 143              Sharjah Cricket Stadium          Sunrisers Hyderabad
# 145  Dubai International Cricket Stadium          Chennai Super Kings
# 147  Dubai International Cricket Stadium               Delhi Capitals
# 148              Sharjah Cricket Stadium                 Punjab Kings
# 150  Dubai International Cricket Stadium  Royal Challengers Bangalore
# 151  Dubai International Cricket Stadium          Sunrisers Hyderabad
# 153              Sharjah Cricket Stadium               Mumbai Indians
# 154  Dubai International Cricket Stadium          Sunrisers Hyderabad
# 156  Dubai International Cricket Stadium               Delhi Capitals
# 159  Dubai International Cricket Stadium               Mumbai Indians
# 160  Dubai International Cricket Stadium             Rajasthan Royals
# 161              Sharjah Cricket Stadium          Chennai Super Kings
# 163              Sharjah Cricket Stadium  Royal Challengers Bangalore
# 164  Dubai International Cricket Stadium               Delhi Capitals
# 165  Dubai International Cricket Stadium          Chennai Super Kings
# 166              Sharjah Cricket Stadium  Royal Challengers Bangalore
# 167  Dubai International Cricket Stadium          Sunrisers Hyderabad
# 170  Dubai International Cricket Stadium  Royal Challengers Bangalore
# 171              Sharjah Cricket Stadium             Rajasthan Royals
# 172  Dubai International Cricket Stadium          Sunrisers Hyderabad
# 175  Dubai International Cricket Stadium  Royal Challengers Bangalore
# 176  Dubai International Cricket Stadium                 Punjab Kings
# 177              Sharjah Cricket Stadium               Mumbai Indians
# 179              Sharjah Cricket Stadium        Kolkata Knight Riders
# 180  Dubai International Cricket Stadium          Sunrisers Hyderabad
# 182  Dubai International Cricket Stadium             Rajasthan Royals
# 184  Dubai International Cricket Stadium               Mumbai Indians
# 185              Sharjah Cricket Stadium             Rajasthan Royals
# 187  Dubai International Cricket Stadium          Chennai Super Kings
# 188  Dubai International Cricket Stadium  Royal Challengers Bangalore
# 190              Sharjah Cricket Stadium          Chennai Super Kings
# 191  Dubai International Cricket Stadium          Sunrisers Hyderabad
# 192  Dubai International Cricket Stadium                 Punjab Kings
# 532  Dubai International Cricket Stadium               Mumbai Indians
# 534  Dubai International Cricket Stadium                 Punjab Kings
# 535              Sharjah Cricket Stadium          Sunrisers Hyderabad
# 536              Sharjah Cricket Stadium               Mumbai Indians
# 539  Dubai International Cricket Stadium          Sunrisers Hyderabad
# 540  Dubai International Cricket Stadium               Mumbai Indians
# 541              Sharjah Cricket Stadium  Royal Challengers Bangalore
# 542  Dubai International Cricket Stadium             Rajasthan Royals
# 543              Sharjah Cricket Stadium          Sunrisers Hyderabad
# 545              Sharjah Cricket Stadium                 Punjab Kings
# 546  Dubai International Cricket Stadium        Kolkata Knight Riders
# 547  Dubai International Cricket Stadium  Royal Challengers Bangalore
# 550              Sharjah Cricket Stadium  Royal Challengers Bangalore
#
#     TossDecision SuperOver                  WinningTeam      WonBy  Margin  \
# 134          bat         N               Mumbai Indians    Wickets     5.0
# 137        field         N               Mumbai Indians       Runs    57.0
# 138        field         N          Sunrisers Hyderabad    Wickets    10.0
# 140        field         N        Kolkata Knight Riders       Runs    60.0
# 142        field         N               Mumbai Indians    Wickets     9.0
# 143        field         N          Sunrisers Hyderabad    Wickets     5.0
# 145        field         N          Chennai Super Kings    Wickets     6.0
# 147        field         N          Sunrisers Hyderabad       Runs    88.0
# 148        field         N                 Punjab Kings    Wickets     8.0
# 150          bat         N          Chennai Super Kings    Wickets     8.0
# 151        field         N                 Punjab Kings       Runs    12.0
# 153        field         N               Mumbai Indians    Wickets    10.0
# 154        field         N          Sunrisers Hyderabad    Wickets     8.0
# 156          bat         N                 Punjab Kings    Wickets     5.0
# 159          bat         Y                 Punjab Kings  SuperOver     NaN
# 160          bat         N  Royal Challengers Bangalore    Wickets     7.0
# 161          bat         N               Delhi Capitals    Wickets     5.0
# 163          bat         N                 Punjab Kings    Wickets     8.0
# 164          bat         N               Delhi Capitals       Runs    13.0
# 165          bat         N          Chennai Super Kings       Runs    20.0
# 166          bat         N  Royal Challengers Bangalore       Runs    82.0
# 167          bat         N             Rajasthan Royals    Wickets     5.0
# 170          bat         N  Royal Challengers Bangalore       Runs    37.0
# 171        field         N               Delhi Capitals       Runs    46.0
# 172          bat         N          Sunrisers Hyderabad       Runs    69.0
# 175        field         N               Delhi Capitals       Runs    59.0
# 176          bat         N          Chennai Super Kings    Wickets    10.0
# 177          bat         N               Mumbai Indians       Runs    34.0
# 179        field         N               Delhi Capitals       Runs    18.0
# 180          bat         N          Sunrisers Hyderabad       Runs     7.0
# 182        field         N        Kolkata Knight Riders       Runs    37.0
# 184        field         Y  Royal Challengers Bangalore  SuperOver     NaN
# 185        field         N             Rajasthan Royals    Wickets     4.0
# 187        field         N               Delhi Capitals       Runs    44.0
# 188        field         N                 Punjab Kings       Runs    97.0
# 190        field         N             Rajasthan Royals       Runs    16.0
# 191        field         N  Royal Challengers Bangalore       Runs    10.0
# 192        field         Y               Delhi Capitals  SuperOver     NaN
# 532        field         N          Sunrisers Hyderabad       Runs    15.0
# 534        field         N                 Punjab Kings    Wickets     5.0
# 535          bat         N          Chennai Super Kings    Wickets     5.0
# 536          bat         N               Delhi Capitals    Wickets     6.0
# 539          bat         N          Sunrisers Hyderabad       Runs     4.0
# 540          bat         N          Chennai Super Kings    Wickets     7.0
# 541        field         N        Kolkata Knight Riders       Runs     2.0
# 542        field         N          Chennai Super Kings       Runs     7.0
# 543        field         N                 Punjab Kings       Runs    72.0
# 545        field         N                 Punjab Kings    Wickets     7.0
# 546          bat         N               Delhi Capitals    Wickets     4.0
# 547        field         N  Royal Challengers Bangalore    Wickets     7.0
# 550        field         N  Royal Challengers Bangalore    Wickets     8.0
#
#     method Player_of_Match                                       Team1Players  \
# 134    NaN        TA Boult  ['MP Stoinis', 'S Dhawan', 'AM Rahane', 'SS Iy...
# 137    NaN       JJ Bumrah  ['Q de Kock', 'RG Sharma', 'SA Yadav', 'Ishan ...
# 138    NaN        S Nadeem  ['RG Sharma', 'Q de Kock', 'SA Yadav', 'Ishan ...
# 140    NaN      PJ Cummins  ['Shubman Gill', 'N Rana', 'RA Tripathi', 'SP ...
# 142    NaN    Ishan Kishan  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
# 143    NaN  Sandeep Sharma  ['JR Philippe', 'D Padikkal', 'V Kohli', 'AB d...
# 145    NaN      RD Gaikwad  ['Shubman Gill', 'N Rana', 'SP Narine', 'RK Si...
# 147    NaN         WP Saha  ['DA Warner', 'WP Saha', 'MK Pandey', 'KS Will...
# 148    NaN        CH Gayle  ['Shubman Gill', 'N Rana', 'RA Tripathi', 'KD ...
# 150    NaN      RD Gaikwad  ['D Padikkal', 'AJ Finch', 'V Kohli', 'AB de V...
# 151    NaN       CJ Jordan  ['KL Rahul', 'Mandeep Singh', 'CH Gayle', 'N P...
# 153    NaN        TA Boult  ['RD Gaikwad', 'F du Plessis', 'AT Rayudu', 'N...
# 154    NaN       MK Pandey  ['RV Uthappa', 'BA Stokes', 'SV Samson', 'JC B...
# 156    NaN        S Dhawan  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
# 159    NaN        KL Rahul  ['RG Sharma', 'Q de Kock', 'SA Yadav', 'Ishan ...
# 160    NaN  AB de Villiers  ['RV Uthappa', 'BA Stokes', 'SV Samson', 'SPD ...
# 161    NaN        S Dhawan  ['SM Curran', 'F du Plessis', 'SR Watson', 'AT...
# 163    NaN        KL Rahul  ['AJ Finch', 'D Padikkal', 'V Kohli', 'Washing...
# 164    NaN        A Nortje  ['PP Shaw', 'S Dhawan', 'AM Rahane', 'SS Iyer'...
# 165    NaN       RA Jadeja  ['SM Curran', 'F du Plessis', 'SR Watson', 'AT...
# 166    NaN  AB de Villiers  ['AJ Finch', 'D Padikkal', 'V Kohli', 'AB de V...
# 167    NaN       R Tewatia  ['DA Warner', 'JM Bairstow', 'MK Pandey', 'KS ...
# 170    NaN         V Kohli  ['D Padikkal', 'AJ Finch', 'V Kohli', 'AB de V...
# 171    NaN        R Ashwin  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
# 172    NaN     JM Bairstow  ['DA Warner', 'JM Bairstow', 'Abdul Samad', 'M...
# 175    NaN        AR Patel  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
# 176    NaN       SR Watson  ['KL Rahul', 'MA Agarwal', 'Mandeep Singh', 'N...
# 177    NaN        TA Boult  ['RG Sharma', 'Q de Kock', 'SA Yadav', 'Ishan ...
# 179    NaN         SS Iyer  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
# 180    NaN         PK Garg  ['DA Warner', 'JM Bairstow', 'MK Pandey', 'KS ...
# 182    NaN     Shivam Mavi  ['Shubman Gill', 'SP Narine', 'N Rana', 'AD Ru...
# 184    NaN  AB de Villiers  ['D Padikkal', 'AJ Finch', 'V Kohli', 'AB de V...
# 185    NaN       SV Samson  ['KL Rahul', 'MA Agarwal', 'GJ Maxwell', 'N Po...
# 187    NaN         PP Shaw  ['PP Shaw', 'S Dhawan', 'RR Pant', 'SS Iyer', ...
# 188    NaN        KL Rahul  ['KL Rahul', 'MA Agarwal', 'N Pooran', 'GJ Max...
# 190    NaN       SV Samson  ['YBK Jaiswal', 'SPD Smith', 'SV Samson', 'DA ...
# 191    NaN       YS Chahal  ['D Padikkal', 'AJ Finch', 'V Kohli', 'AB de V...
# 192    NaN      MP Stoinis  ['PP Shaw', 'S Dhawan', 'SO Hetmyer', 'SS Iyer...
# 532    NaN         B Kumar  ['BR Dunk', 'RG Sharma', 'CJ Anderson', 'AT Ra...
# 534    NaN  Sandeep Sharma  ['CA Pujara', 'V Sehwag', 'WP Saha', 'GJ Maxwe...
# 535    NaN        DR Smith  ['AJ Finch', 'S Dhawan', 'DA Warner', 'KL Rahu...
# 536    NaN         M Vijay  ['Q de Kock', 'M Vijay', 'JP Duminy', 'KP Piet...
# 539    NaN        AJ Finch  ['S Dhawan', 'AJ Finch', 'DA Warner', 'KL Rahu...
# 540    NaN       MM Sharma  ['DR Smith', 'BB McCullum', 'SK Raina', 'F du ...
# 541    NaN         CA Lynn  ['PA Patel', 'YV Takawale', 'V Kohli', 'Yuvraj...
# 542    NaN       RA Jadeja  ['AM Nayar', 'AM Rahane', 'SV Samson', 'SR Wat...
# 543    NaN      GJ Maxwell  ['CA Pujara', 'V Sehwag', 'GJ Maxwell', 'DA Mi...
# 545    NaN      GJ Maxwell  ['AM Nayar', 'AM Rahane', 'SV Samson', 'SR Wat...
# 546    NaN       JP Duminy  ['JH Kallis', 'G Gambhir', 'MK Pandey', 'RV Ut...
# 547    NaN        PA Patel  ['NJ Maddinson', 'PA Patel', 'V Kohli', 'Yuvra...
# 550    NaN       YS Chahal  ['MA Agarwal', 'M Vijay', 'KD Karthik', 'MK Ti...
#
#                                           Team2Players                Umpire1  \
# 134  ['RG Sharma', 'Q de Kock', 'SA Yadav', 'Ishan ...            CB Gaffaney
# 137  ['PP Shaw', 'S Dhawan', 'AM Rahane', 'SS Iyer'...            CB Gaffaney
# 138  ['DA Warner', 'WP Saha', 'MK Pandey', 'KS Will...          C Shamshuddin
# 140  ['RV Uthappa', 'BA Stokes', 'SPD Smith', 'SV S...            Nitin Menon
# 142  ['Ishan Kishan', 'Q de Kock', 'SA Yadav', 'SS ...               YC Barde
# 143  ['DA Warner', 'WP Saha', 'MK Pandey', 'KS Will...  KN Ananthapadmanabhan
# 145  ['SR Watson', 'RD Gaikwad', 'AT Rayudu', 'MS D...          C Shamshuddin
# 147  ['AM Rahane', 'S Dhawan', 'MP Stoinis', 'SO He...           AK Chaudhary
# 148  ['KL Rahul', 'Mandeep Singh', 'CH Gayle', 'N P...  KN Ananthapadmanabhan
# 150  ['RD Gaikwad', 'F du Plessis', 'AT Rayudu', 'M...          C Shamshuddin
# 151  ['DA Warner', 'JM Bairstow', 'MK Pandey', 'Abd...            AY Dandekar
# 153  ['Q de Kock', 'Ishan Kishan', 'SA Yadav', 'SS ...          C Shamshuddin
# 154  ['DA Warner', 'JM Bairstow', 'MK Pandey', 'V S...            Nitin Menon
# 156  ['KL Rahul', 'MA Agarwal', 'CH Gayle', 'N Poor...          C Shamshuddin
# 159  ['KL Rahul', 'MA Agarwal', 'CH Gayle', 'N Poor...            Nitin Menon
# 160  ['D Padikkal', 'AJ Finch', 'V Kohli', 'AB de V...           AK Chaudhary
# 161  ['PP Shaw', 'S Dhawan', 'AM Rahane', 'SS Iyer'...  KN Ananthapadmanabhan
# 163  ['KL Rahul', 'MA Agarwal', 'CH Gayle', 'N Poor...  KN Ananthapadmanabhan
# 164  ['BA Stokes', 'JC Buttler', 'SPD Smith', 'SV S...           AK Chaudhary
# 165  ['DA Warner', 'JM Bairstow', 'MK Pandey', 'KS ...           AK Chaudhary
# 166  ['T Banton', 'Shubman Gill', 'N Rana', 'EJG Mo...         RK Illingworth
# 167  ['BA Stokes', 'JC Buttler', 'SPD Smith', 'SV S...               YC Barde
# 170  ['SR Watson', 'F du Plessis', 'AT Rayudu', 'N ...           AK Chaudhary
# 171  ['YBK Jaiswal', 'JC Buttler', 'SPD Smith', 'SV...  KN Ananthapadmanabhan
# 172  ['KL Rahul', 'MA Agarwal', 'P Simran Singh', '...           AK Chaudhary
# 175  ['D Padikkal', 'AJ Finch', 'V Kohli', 'AB de V...            Nitin Menon
# 176  ['SR Watson', 'F du Plessis', 'AT Rayudu', 'KM...            AY Dandekar
# 177  ['DA Warner', 'JM Bairstow', 'MK Pandey', 'KS ...  KN Ananthapadmanabhan
# 179  ['Shubman Gill', 'SP Narine', 'N Rana', 'AD Ru...            VA Kulkarni
# 180  ['F du Plessis', 'SR Watson', 'AT Rayudu', 'KM...           AK Chaudhary
# 182  ['JC Buttler', 'SPD Smith', 'SV Samson', 'RV U...  KN Ananthapadmanabhan
# 184  ['RG Sharma', 'Q de Kock', 'SA Yadav', 'Ishan ...            Nitin Menon
# 185  ['JC Buttler', 'SPD Smith', 'SV Samson', 'R Te...         RK Illingworth
# 187  ['M Vijay', 'SR Watson', 'F du Plessis', 'RD G...  KN Ananthapadmanabhan
# 188  ['D Padikkal', 'AJ Finch', 'JR Philippe', 'V K...           AK Chaudhary
# 190  ['M Vijay', 'SR Watson', 'F du Plessis', 'SM C...          C Shamshuddin
# 191  ['DA Warner', 'JM Bairstow', 'MK Pandey', 'PK ...            AY Dandekar
# 192  ['KL Rahul', 'MA Agarwal', 'KK Nair', 'N Poora...           AK Chaudhary
# 532  ['AJ Finch', 'S Dhawan', 'KL Rahul', 'DA Warne...        HDPK Dharmasena
# 534  ['CH Gayle', 'PA Patel', 'V Kohli', 'YV Takawa...              BF Bowden
# 535  ['DR Smith', 'BB McCullum', 'SK Raina', 'MS Dh...           AK Chaudhary
# 536  ['RG Sharma', 'AP Tare', 'CJ Anderson', 'AT Ra...              Aleem Dar
# 539  ['Q de Kock', 'M Vijay', 'KP Pietersen', 'KD K...              M Erasmus
# 540  ['MEK Hussey', 'AP Tare', 'CJ Anderson', 'RG S...              BF Bowden
# 541  ['JH Kallis', 'G Gambhir', 'MK Pandey', 'CA Ly...              Aleem Dar
# 542  ['DR Smith', 'BB McCullum', 'SK Raina', 'F du ...        HDPK Dharmasena
# 543  ['AJ Finch', 'S Dhawan', 'DA Warner', 'KL Rahu...              M Erasmus
# 545  ['CA Pujara', 'V Sehwag', 'WP Saha', 'GJ Maxwe...              BF Bowden
# 546  ['M Vijay', 'MA Agarwal', 'KD Karthik', 'LRPL ...              Aleem Dar
# 547  ['MEK Hussey', 'AP Tare', 'AT Rayudu', 'RG Sha...              Aleem Dar
# 550  ['PA Patel', 'NJ Maddinson', 'V Kohli', 'Yuvra...              Aleem Dar
#
#             Umpire2
# 134     Nitin Menon
# 137     Nitin Menon
# 138  RK Illingworth
# 140      PR Reiffel
# 142      PR Reiffel
# 143    K Srinivasan
# 145  RK Illingworth
# 147     Nitin Menon
# 148  RK Illingworth
# 150  RK Illingworth
# 151      PR Reiffel
# 153     VA Kulkarni
# 154      PR Reiffel
# 156  RK Illingworth
# 159      PR Reiffel
# 160     Nitin Menon
# 161  RK Illingworth
# 163   C Shamshuddin
# 164     Nitin Menon
# 165      PR Reiffel
# 166    K Srinivasan
# 167      PR Reiffel
# 170      PR Reiffel
# 171   C Shamshuddin
# 172     Nitin Menon
# 175        YC Barde
# 176     Nitin Menon
# 177  RK Illingworth
# 179  RK Illingworth
# 180      PR Reiffel
# 182   C Shamshuddin
# 184      PR Reiffel
# 185    K Srinivasan
# 187  RK Illingworth
# 188      PR Reiffel
# 190     VA Kulkarni
# 191     Nitin Menon
# 192     Nitin Menon
# 532       M Erasmus
# 534          S Ravi
# 535     VA Kulkarni
# 536     VA Kulkarni
# 539          S Ravi
# 540       M Erasmus
# 541     VA Kulkarni
# 542  RK Illingworth
# 543          S Ravi
# 545       M Erasmus
# 546     VA Kulkarni
# 547    AK Chaudhary
# 550          S Ravi

# %%
c1=df['City'].isnull()
df[c1]['Venue'].value_counts()
# Out:
# Venue
# Dubai International Cricket Stadium    33
# Sharjah Cricket Stadium                18
# Name: count, dtype: int64

# %%
vf=(df['Venue']=='Dubai International Criket Stadium') #City = Dubai
df[vf]['City']='Dubai'

# %%
df[vf]['City']
# Out:
# Series([], Name: City, dtype: object)

# %%
df['City']
# Out:
# 0       Ahmedabad
# 1       Ahmedabad
# 2         Kolkata
# 3         Kolkata
# 4          Mumbai
#           ...
# 945       Kolkata
# 946        Mumbai
# 947         Delhi
# 948    Chandigarh
# 949     Bangalore
# Name: City, Length: 950, dtype: object

# %%
df.columns
# Out:
# Index(['   ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
vf=(df['Venue']=='Dubai International Criket Stadium')
df[vf].index
# Out:
# Index([], dtype='int64')

# %%
df[vf]
# Out:
# Empty DataFrame
# Columns: [   ID, City, Date, Season, MatchNumber, Team1, Team2, Venue, TossWinner, TossDecision, SuperOver, WinningTeam, WonBy, Margin, method, Player_of_Match, Team1Players, Team2Players, Umpire1, Umpire2]
# Index: []

# %%
df.isnull().sum()
# Out:
#    ID                0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
df.loc[vf,'City'] = 'sharjah'

# %%
df.isnull().sum()
# Out:
#    ID                0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
df['SuperOver'].fillna('NoResult',inplace=True)
df['WinningTeam'].fillna('NoResult',inplace=True)
df['Player_of_Match'].fillna('NoResult',inplace=True)
df['Margin'].fillna('NoMargin',inplace=True)

# %%
df.isnull().sum()
# Out:
#    ID                0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            0
# WinningTeam          0
# WonBy                0
# Margin               0
# method             931
# Player_of_Match      0
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %% [markdown]
# ## Data has been cleaned for further processing

# %%
dfb=pd.read_csv('IPL_Ball_by_Ball_2008_2022.csv')
dfb.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# 0                 0        NaN  NaN               NaN  Rajasthan Royals
# 1                 0        NaN  NaN               NaN  Rajasthan Royals
# 2                 0        NaN  NaN               NaN  Rajasthan Royals
# 3                 0        NaN  NaN               NaN  Rajasthan Royals
# 4                 0        NaN  NaN               NaN  Rajasthan Royals

# %%
dfb.shape
# Out:
# (225954, 17)

# %% [markdown]
# > In our dataset we have 225954-rows and 17 columns

# %%
dfb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225954 entries, 0 to 225953
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ID                 225954 non-null  int64
#  1   innings            225954 non-null  int64
#  2   overs              225954 non-null  int64
#  3   ballnumber         225954 non-null  int64
#  4   batter             225954 non-null  object
#  5   bowler             225954 non-null  object
#  6   non-striker        225954 non-null  object
#  7   extra_type         12049 non-null   object
#  8   batsman_run        225954 non-null  int64
#  9   extras_run         225954 non-null  int64
#  10  total_run          225954 non-null  int64
#  11  non_boundary       225954 non-null  int64
#  12  isWicketDelivery   225954 non-null  int64
#  13  player_out         11151 non-null   object
#  14  kind               11151 non-null   object
#  15  fielders_involved  7988 non-null    object
#  16  BattingTeam        225954 non-null  object
# dtypes: int64(9), object(8)
# memory usage: 29.3+ MB

# %%
# checking duplicates
dfb.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## there are no duplicate values

# %%
## null value checking

dfb.isnull().sum()
# Out:
# ID                        0
# innings                   0
# overs                     0
# ballnumber                0
# batter                    0
# bowler                    0
# non-striker               0
# extra_type           213905
# batsman_run               0
# extras_run                0
# total_run                 0
# non_boundary              0
# isWicketDelivery          0
# player_out           214803
# kind                 214803
# fielders_involved    217966
# BattingTeam               0
# dtype: int64

# %%
dfb.drop(columns=['extra_type','player_out','kind','fielders_involved'])
# Out:
#              ID  innings  overs  ballnumber       batter          bowler  \
# 0       1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1       1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2       1312200        1      0           3   JC Buttler  Mohammed Shami
# 3       1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4       1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...         ...      ...    ...         ...          ...             ...
# 225949   335982        2     14           5      P Kumar        I Sharma
# 225950   335982        2     14           6     SB Joshi        I Sharma
# 225951   335982        2     14           7      P Kumar        I Sharma
# 225952   335982        2     15           1     SB Joshi       LR Shukla
# 225953   335982        2     15           2     SB Joshi       LR Shukla
#
#         non-striker  batsman_run  extras_run  total_run  non_boundary  \
# 0        JC Buttler            0           0          0             0
# 1        JC Buttler            0           1          1             0
# 2       YBK Jaiswal            1           0          1             0
# 3        JC Buttler            0           0          0             0
# 4        JC Buttler            0           0          0             0
# ...             ...          ...         ...        ...           ...
# 225949     SB Joshi            0           1          1             0
# 225950      P Kumar            1           0          1             0
# 225951     SB Joshi            0           0          0             0
# 225952      P Kumar            0           1          1             0
# 225953      P Kumar            0           0          0             0
#
#         isWicketDelivery                  BattingTeam
# 0                      0             Rajasthan Royals
# 1                      0             Rajasthan Royals
# 2                      0             Rajasthan Royals
# 3                      0             Rajasthan Royals
# 4                      0             Rajasthan Royals
# ...                  ...                          ...
# 225949                 0  Royal Challengers Bangalore
# 225950                 0  Royal Challengers Bangalore
# 225951                 0  Royal Challengers Bangalore
# 225952                 0  Royal Challengers Bangalore
# 225953                 1  Royal Challengers Bangalore
#
# [225954 rows x 13 columns]

# %%
dfb.isnull().sum()
# Out:
# ID                        0
# innings                   0
# overs                     0
# ballnumber                0
# batter                    0
# bowler                    0
# non-striker               0
# extra_type           213905
# batsman_run               0
# extras_run                0
# total_run                 0
# non_boundary              0
# isWicketDelivery          0
# player_out           214803
# kind                 214803
# fielders_involved    217966
# BattingTeam               0
# dtype: int64

# %%
dfb.columns
# Out:
# Index(['ID', 'innings', 'overs', 'ballnumber', 'batter', 'bowler',
#        'non-striker', 'extra_type', 'batsman_run', 'extras_run', 'total_run',
#        'non_boundary', 'isWicketDelivery', 'player_out', 'kind',
#        'fielders_involved', 'BattingTeam'],
#       dtype='object')

# %%
dfb.rename(columns={'innings':'Innings','overs':'Over', 'ballnumber':'Ballnumber','batter':'Batter', 'bowler'
:'Bowler','non-striker':'Non-Striker', 'extra_type':'Extra_Type','batsman_run':'Batsman_Run','extras_run':'Extras_Run','total_run':
'Total_Run','non_boundary':'Non_Boundary', 'isWicketDelivery':'IswicketDelivery'})
# Out:
#              ID  Innings  Over  Ballnumber       Batter          Bowler  \
# 0       1312200        1     0           1  YBK Jaiswal  Mohammed Shami
# 1       1312200        1     0           2  YBK Jaiswal  Mohammed Shami
# 2       1312200        1     0           3   JC Buttler  Mohammed Shami
# 3       1312200        1     0           4  YBK Jaiswal  Mohammed Shami
# 4       1312200        1     0           5  YBK Jaiswal  Mohammed Shami
# ...         ...      ...   ...         ...          ...             ...
# 225949   335982        2    14           5      P Kumar        I Sharma
# 225950   335982        2    14           6     SB Joshi        I Sharma
# 225951   335982        2    14           7      P Kumar        I Sharma
# 225952   335982        2    15           1     SB Joshi       LR Shukla
# 225953   335982        2    15           2     SB Joshi       LR Shukla
#
#         Non-Striker Extra_Type  Batsman_Run  Extras_Run  Total_Run  \
# 0        JC Buttler        NaN            0           0          0
# 1        JC Buttler    legbyes            0           1          1
# 2       YBK Jaiswal        NaN            1           0          1
# 3        JC Buttler        NaN            0           0          0
# 4        JC Buttler        NaN            0           0          0
# ...             ...        ...          ...         ...        ...
# 225949     SB Joshi    legbyes            0           1          1
# 225950      P Kumar        NaN            1           0          1
# 225951     SB Joshi        NaN            0           0          0
# 225952      P Kumar      wides            0           1          1
# 225953      P Kumar        NaN            0           0          0
#
#         Non_Boundary  IswicketDelivery player_out    kind fielders_involved  \
# 0                  0                 0        NaN     NaN               NaN
# 1                  0                 0        NaN     NaN               NaN
# 2                  0                 0        NaN     NaN               NaN
# 3                  0                 0        NaN     NaN               NaN
# 4                  0                 0        NaN     NaN               NaN
# ...              ...               ...        ...     ...               ...
# 225949             0                 0        NaN     NaN               NaN
# 225950             0                 0        NaN     NaN               NaN
# 225951             0                 0        NaN     NaN               NaN
# 225952             0                 0        NaN     NaN               NaN
# 225953             0                 1   SB Joshi  caught       BB McCullum
#
#                         BattingTeam
# 0                  Rajasthan Royals
# 1                  Rajasthan Royals
# 2                  Rajasthan Royals
# 3                  Rajasthan Royals
# 4                  Rajasthan Royals
# ...                             ...
# 225949  Royal Challengers Bangalore
# 225950  Royal Challengers Bangalore
# 225951  Royal Challengers Bangalore
# 225952  Royal Challengers Bangalore
# 225953  Royal Challengers Bangalore
#
# [225954 rows x 17 columns]

# %%
dfb.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# 0                 0        NaN  NaN               NaN  Rajasthan Royals
# 1                 0        NaN  NaN               NaN  Rajasthan Royals
# 2                 0        NaN  NaN               NaN  Rajasthan Royals
# 3                 0        NaN  NaN               NaN  Rajasthan Royals
# 4                 0        NaN  NaN               NaN  Rajasthan Royals

# %%
df.head()
# Out:
#         ID       City       Date Season  MatchNumber  \
# 0  1312200  Ahmedabad 2022-05-29   2022        Final
# 1  1312199  Ahmedabad 2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata 2022-05-25   2022   Eliminator
# 3  1312197    Kolkata 2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai 2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3             Eden Gardens, Kolkata        Gujarat Titans        field
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat
#
#   SuperOver                  WinningTeam    WonBy Margin method  \
# 0         N               Gujarat Titans  Wickets    7.0    NaN
# 1         N             Rajasthan Royals  Wickets    7.0    NaN
# 2         N  Royal Challengers Bangalore     Runs   14.0    NaN
# 3         N               Gujarat Titans  Wickets    7.0    NaN
# 4         N                 Punjab Kings  Wickets    5.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
#
#          Umpire2
# 0    Nitin Menon
# 1    Nitin Menon
# 2       MA Gough
# 3      VK Sharma
# 4  NA Patwardhan

# %%
dfb.isnull().sum()
# Out:
# ID                        0
# innings                   0
# overs                     0
# ballnumber                0
# batter                    0
# bowler                    0
# non-striker               0
# extra_type           213905
# batsman_run               0
# extras_run                0
# total_run                 0
# non_boundary              0
# isWicketDelivery          0
# player_out           214803
# kind                 214803
# fielders_involved    217966
# BattingTeam               0
# dtype: int64

# %%
dfb.nunique()
# Out:
# ID                   950
# innings                6
# overs                 20
# ballnumber            10
# batter               605
# bowler               472
# non-striker          595
# extra_type             5
# batsman_run            7
# extras_run             7
# total_run              8
# non_boundary           2
# isWicketDelivery       2
# player_out           573
# kind                  10
# fielders_involved    535
# BattingTeam           18
# dtype: int64

# %%
dfb['innings'].nunique()
# Out:
# 6

# %%
dfb['innings'].value_counts()
# Out:
# innings
# 1    116883
# 2    108910
# 3        77
# 4        72
# 5         8
# 6         4
# Name: count, dtype: int64

# %%
dfb['overs'].value_counts()
# Out:
# overs
# 0     12085
# 1     11935
# 2     11803
# 3     11773
# 4     11766
# 5     11720
# 6     11671
# 7     11651
# 8     11608
# 9     11578
# 10    11507
# 11    11480
# 12    11452
# 13    11355
# 14    11259
# 15    11093
# 16    10961
# 17    10650
# 18    10001
# 19     8606
# Name: count, dtype: int64

# %%
dfb['ballnumber'].value_counts()
# Out:
# ballnumber
# 1     36599
# 2     36507
# 3     36413
# 4     36322
# 5     36201
# 6     36083
# 7      6585
# 8      1055
# 9       171
# 10       18
# Name: count, dtype: int64

# %%
dfb['batsman_run'].value_counts()
# Out:
# batsman_run
# 0    90778
# 1    83928
# 4    25500
# 2    14313
# 6    10666
# 3      708
# 5       61
# Name: count, dtype: int64

# %%
dfb['BattingTeam'].value_counts()
# Out:
# BattingTeam
# Mumbai Indians                 27826
# Royal Challengers Bangalore    26512
# Kolkata Knight Riders          26192
# Chennai Super Kings            25128
# Rajasthan Royals               22777
# Kings XI Punjab                22646
# Delhi Daredevils               18786
# Sunrisers Hyderabad            18196
# Deccan Chargers                 9034
# Delhi Capitals                  7587
# Pune Warriors                   5443
# Gujarat Lions                   3566
# Punjab Kings                    3388
# Gujarat Titans                  1971
# Rising Pune Supergiant          1900
# Lucknow Super Giants            1840
# Kochi Tuskers Kerala            1582
# Rising Pune Supergiants         1580
# Name: count, dtype: int64

# %%
dfb['BattingTeam'].value_counts().sort_index()
# Out:
# BattingTeam
# Chennai Super Kings            25128
# Deccan Chargers                 9034
# Delhi Capitals                  7587
# Delhi Daredevils               18786
# Gujarat Lions                   3566
# Gujarat Titans                  1971
# Kings XI Punjab                22646
# Kochi Tuskers Kerala            1582
# Kolkata Knight Riders          26192
# Lucknow Super Giants            1840
# Mumbai Indians                 27826
# Pune Warriors                   5443
# Punjab Kings                    3388
# Rajasthan Royals               22777
# Rising Pune Supergiant          1900
# Rising Pune Supergiants         1580
# Royal Challengers Bangalore    26512
# Sunrisers Hyderabad            18196
# Name: count, dtype: int64

# %%
dfb['BattingTeam']=dfb['BattingTeam'].replace('Kings XI Punjab','Punjab Kings')

# %%
dfb['BattingTeam']=dfb['BattingTeam'].replace('Delhi Daredevils','Delhi Capitals')

# %%
dfb['BattingTeam']=dfb['BattingTeam'].replace('Rising Pune Supergiant','Rising Pune Supergiants')

# %%
dfb['BattingTeam'].value_counts().sort_index()
# Out:
# BattingTeam
# Chennai Super Kings            25128
# Deccan Chargers                 9034
# Delhi Capitals                 26373
# Gujarat Lions                   3566
# Gujarat Titans                  1971
# Kochi Tuskers Kerala            1582
# Kolkata Knight Riders          26192
# Lucknow Super Giants            1840
# Mumbai Indians                 27826
# Pune Warriors                   5443
# Punjab Kings                   26034
# Rajasthan Royals               22777
# Rising Pune Supergiants         3480
# Royal Challengers Bangalore    26512
# Sunrisers Hyderabad            18196
# Name: count, dtype: int64

# %%
dfb.head(10)
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# 5  1312200        1      0           6  YBK Jaiswal  Mohammed Shami
# 6  1312200        1      1           1   JC Buttler      Yash Dayal
# 7  1312200        1      1           2   JC Buttler      Yash Dayal
# 8  1312200        1      1           3   JC Buttler      Yash Dayal
# 9  1312200        1      1           4   JC Buttler      Yash Dayal
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
# 5   JC Buttler        NaN            0           0          0             0
# 6  YBK Jaiswal        NaN            0           0          0             0
# 7  YBK Jaiswal        NaN            0           0          0             0
# 8  YBK Jaiswal        NaN            4           0          4             0
# 9  YBK Jaiswal        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# 0                 0        NaN  NaN               NaN  Rajasthan Royals
# 1                 0        NaN  NaN               NaN  Rajasthan Royals
# 2                 0        NaN  NaN               NaN  Rajasthan Royals
# 3                 0        NaN  NaN               NaN  Rajasthan Royals
# 4                 0        NaN  NaN               NaN  Rajasthan Royals
# 5                 0        NaN  NaN               NaN  Rajasthan Royals
# 6                 0        NaN  NaN               NaN  Rajasthan Royals
# 7                 0        NaN  NaN               NaN  Rajasthan Royals
# 8                 0        NaN  NaN               NaN  Rajasthan Royals
# 9                 0        NaN  NaN               NaN  Rajasthan Royals

# %%
# unique value in ballnumber
dfb['ballnumber'].value_counts().sort_index()
# Out:
# ballnumber
# 1     36599
# 2     36507
# 3     36413
# 4     36322
# 5     36201
# 6     36083
# 7      6585
# 8      1055
# 9       171
# 10       18
# Name: count, dtype: int64

# %%
dfb['innings'].value_counts().sort_index()
# Out:
# innings
# 1    116883
# 2    108910
# 3        77
# 4        72
# 5         8
# 6         4
# Name: count, dtype: int64

# %%
dfb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225954 entries, 0 to 225953
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ID                 225954 non-null  int64
#  1   innings            225954 non-null  int64
#  2   overs              225954 non-null  int64
#  3   ballnumber         225954 non-null  int64
#  4   batter             225954 non-null  object
#  5   bowler             225954 non-null  object
#  6   non-striker        225954 non-null  object
#  7   extra_type         12049 non-null   object
#  8   batsman_run        225954 non-null  int64
#  9   extras_run         225954 non-null  int64
#  10  total_run          225954 non-null  int64
#  11  non_boundary       225954 non-null  int64
#  12  isWicketDelivery   225954 non-null  int64
#  13  player_out         11151 non-null   object
#  14  kind               11151 non-null   object
#  15  fielders_involved  7988 non-null    object
#  16  BattingTeam        225954 non-null  object
# dtypes: int64(9), object(8)
# memory usage: 29.3+ MB

# %%
dfb.describe()
# Out:
#                  ID        innings          overs     ballnumber  \
# count  2.259540e+05  225954.000000  225954.000000  225954.000000
# mean   8.320470e+05       1.483868       9.185679       3.619750
# std    3.379542e+05       0.503104       5.681797       1.810633
# min    3.359820e+05       1.000000       0.000000       1.000000
# 25%    5.012620e+05       1.000000       4.000000       2.000000
# 50%    8.297370e+05       1.000000       9.000000       4.000000
# 75%    1.178395e+06       2.000000      14.000000       5.000000
# max    1.312200e+06       6.000000      19.000000      10.000000
#
#          batsman_run     extras_run     total_run   non_boundary  \
# count  225954.000000  225954.000000  225954.00000  225954.000000
# mean        1.243523       0.066907       1.31043       0.000093
# std         1.618166       0.341470       1.60605       0.009640
# min         0.000000       0.000000       0.00000       0.000000
# 25%         0.000000       0.000000       0.00000       0.000000
# 50%         1.000000       0.000000       1.00000       0.000000
# 75%         1.000000       0.000000       1.00000       0.000000
# max         6.000000       7.000000       7.00000       1.000000
#
#        isWicketDelivery
# count     225954.000000
# mean           0.049351
# std            0.216600
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.000000
# max            1.000000

# %%
dfb['overs'].value_counts()
# Out:
# overs
# 0     12085
# 1     11935
# 2     11803
# 3     11773
# 4     11766
# 5     11720
# 6     11671
# 7     11651
# 8     11608
# 9     11578
# 10    11507
# 11    11480
# 12    11452
# 13    11355
# 14    11259
# 15    11093
# 16    10961
# 17    10650
# 18    10001
# 19     8606
# Name: count, dtype: int64

# %%
lambda x : x+1
# Out:
# <function __main__.<lambda>(x)>

# %%
dfb['']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Program Files\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[405], line 1
# ----> 1 dfb['']
#
# File c:\Program Files\Anaconda\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Program Files\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: ''

# %%
dfb['overs'].apply(func) # operation i++ => i=i+1
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#           ..
# 225949    15
# 225950    15
# 225951    15
# 225952    16
# 225953    16
# Name: overs, Length: 225954, dtype: int64

# %%
dfb['overs']=dfb['overs'].apply(lambda x : x+1)# operation i++ => i=i+1

# %%
dfb['overs'].apply(lambda x:x+1) # operation i++ =>i=i+1
# Out:
# 0          NaN
# 1          NaN
# 2         22.0
# 3          NaN
# 4          NaN
#           ...
# 225949     NaN
# 225950     NaN
# 225951     NaN
# 225952     NaN
# 225953     NaN
# Name: overs, Length: 225954, dtype: float64

# %%
dfb.describe()[['overs','ballnumber','ballnumber','extras_run','total_run']]
# Out:
#        overs     ballnumber     ballnumber     extras_run     total_run
# count    1.0  225954.000000  225954.000000  225954.000000  225954.00000
# mean    21.0       3.619750       3.619750       0.066907       1.31043
# std      NaN       1.810633       1.810633       0.341470       1.60605
# min     21.0       1.000000       1.000000       0.000000       0.00000
# 25%     21.0       2.000000       2.000000       0.000000       0.00000
# 50%     21.0       4.000000       4.000000       0.000000       1.00000
# 75%     21.0       5.000000       5.000000       0.000000       1.00000
# max     21.0      10.000000      10.000000       7.000000       7.00000

# %%
dfb['extras_run'].value_counts()
# Out:
# extras_run
# 0    213905
# 1     10760
# 2       499
# 4       436
# 5       275
# 3        78
# 7         1
# Name: count, dtype: int64

# %% [markdown]
# > done with data cleaning and stastical information

# %% [markdown]
# # Exploratory Data Analysis
# Now we will analyze our IPL dataset containing information about macthes, venue and scoring of IPL 15 seasons 2008 to 2022

# %% [markdown]
# #### what are the total teames played from 2008 -2022 and i want list of

# %%
print(df.shape)
dfb.shape
# Out:
# (950, 20)
# (225954, 17)

# %%
df.columns
# Out:
# Index(['   ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
df['Team1'].value_counts().index
# Out:
# Index(['Royal Challengers Bangalore', 'Delhi Capitals', 'Mumbai Indians',
#        'Chennai Super Kings', 'Punjab Kings', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Sunrisers Hyderabad', 'Deccan Chargers',
#        'Pune Warriors', 'Gujarat Lions', 'Rising Pune Supergiant',
#        'Lucknow Super Giants', 'Gujarat Titans', 'Kochi Tuskers Kerala'],
#       dtype='object', name='Team1')

# %%
df.columns
# Out:
# Index(['   ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
Teamsdf=pd.DataFrame(df['Team1'].value_counts().index)

# %%
Teamsdf.sum()
# Out:
# Team1    Royal Challengers BangaloreDelhi CapitalsMumba...
# dtype: object

# %% [markdown]
# > there are 15 teams and in teamsdf you can see the list of teams

# %%
len(Teamsdf)
Teamsdf.shape[0]
# Out:
# 15

# %%
len(Teamsdf)
# Out:
# 15

# %%
Teamsdf
# Out:
#                           Team1
# 0   Royal Challengers Bangalore
# 1                Delhi Capitals
# 2                Mumbai Indians
# 3           Chennai Super Kings
# 4                  Punjab Kings
# 5         Kolkata Knight Riders
# 6              Rajasthan Royals
# 7           Sunrisers Hyderabad
# 8               Deccan Chargers
# 9                 Pune Warriors
# 10                Gujarat Lions
# 11       Rising Pune Supergiant
# 12         Lucknow Super Giants
# 13               Gujarat Titans
# 14         Kochi Tuskers Kerala

# %%
Teamsdf.rename(columns={'Team1':'Teams'},inplace=True)

# %%
Teamsdf
# Out:
#                           Teams
# 0   Royal Challengers Bangalore
# 1                Delhi Capitals
# 2                Mumbai Indians
# 3           Chennai Super Kings
# 4                  Punjab Kings
# 5         Kolkata Knight Riders
# 6              Rajasthan Royals
# 7           Sunrisers Hyderabad
# 8               Deccan Chargers
# 9                 Pune Warriors
# 10                Gujarat Lions
# 11       Rising Pune Supergiant
# 12         Lucknow Super Giants
# 13               Gujarat Titans
# 14         Kochi Tuskers Kerala

# %% [markdown]
# ##### Total matches played by each team ?

# %%
df['Team1'].value_counts()
# Out:
# Team1
# Royal Challengers Bangalore    126
# Delhi Capitals                 114
# Mumbai Indians                 112
# Chennai Super Kings            111
# Punjab Kings                   110
# Kolkata Knight Riders          105
# Rajasthan Royals                89
# Sunrisers Hyderabad             69
# Deccan Chargers                 39
# Pune Warriors                   23
# Gujarat Lions                   16
# Rising Pune Supergiant          14
# Lucknow Super Giants             8
# Gujarat Titans                   7
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %%
df['Team2'].value_counts()
# Out:
# Team2
# Mumbai Indians                 119
# Kolkata Knight Riders          118
# Delhi Capitals                 110
# Punjab Kings                   108
# Rajasthan Royals               103
# Royal Challengers Bangalore    100
# Chennai Super Kings             97
# Sunrisers Hyderabad             83
# Deccan Chargers                 36
# Pune Warriors                   23
# Rising Pune Supergiant          16
# Gujarat Lions                   14
# Gujarat Titans                   9
# Lucknow Super Giants             7
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %%
df[['Team1','Team2']]
# Out:
#                            Team1                        Team2
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947               Delhi Capitals             Rajasthan Royals
# 948                 Punjab Kings          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
# [950 rows x 2 columns]

# %%
pd.concat([df['Team1'],df['Team2']])
# Out:
# 0                 Rajasthan Royals
# 1      Royal Challengers Bangalore
# 2      Royal Challengers Bangalore
# 3                 Rajasthan Royals
# 4              Sunrisers Hyderabad
#                   ...
# 945                Deccan Chargers
# 946    Royal Challengers Bangalore
# 947               Rajasthan Royals
# 948            Chennai Super Kings
# 949          Kolkata Knight Riders
# Length: 1900, dtype: object

# %%
Teams_matches=pd.concat([df['Team1'],df['Team2']]).value_counts()
Teams_matches=pd.DataFrame(Teams_matches).reset_index()
Teams_matches.rename(columns={'index':'Teams','count':'Total_matches'},inplace=True)

# %% [markdown]
# ### Visualization

# %% [markdown]
# ### matplotlib

# %%
def get_color(name, number):
    pal = list(sns.color_palette(palette=name, n_colors=number).as_hex())
    return pal

# %%
pal_vi = get_color('viridis_r', len(df))
pal_vi
# Out:
# ['#fde725',
#  '#fde725',
#  '#fde725',
#  '#fbe723',
#  '#fbe723',
#  '#fbe723',
#  '#fbe723',
#  '#f8e621',
#  '#f8e621',
#  '#f8e621',
#  '#f8e621',
#  '#f6e620',
#  '#f6e620',
#  '#f6e620',
#  '#f4e61e',
#  '#f4e61e',
#  '#f4e61e',
#  '#f4e61e',
#  '#f1e51d',
#  '#f1e51d',
#  '#f1e51d',
#  '#f1e51d',
#  '#efe51c',
#  '#efe51c',
#  '#efe51c',
#  '#efe51c',
#  '#ece51b',
#  '#ece51b',
#  '#ece51b',
#  '#eae51a',
#  '#eae51a',
#  '#eae51a',
#  '#eae51a',
#  '#e7e419',
#  '#e7e419',
#  '#e7e419',
#  '#e7e419',
#  '#e5e419',
#  '#e5e419',
#  '#e5e419',
#  '#e2e418',
#  '#e2e418',
#  '#e2e418',
#  '#e2e418',
#  '#dfe318',
#  '#dfe318',
#  '#dfe318',
#  '#dfe318',
#  '#dde318',
#  '#dde318',
#  '#dde318',
#  '#dde318',
#  '#dae319',
#  '#dae319',
#  '#dae319',
#  '#d8e219',
#  '#d8e219',
#  '#d8e219',
#  '#d8e219',
#  '#d5e21a',
#  '#d5e21a',
#  '#d5e21a',
#  '#d5e21a',
#  '#d2e21b',
#  '#d2e21b',
#  '#d2e21b',
#  '#d0e11c',
#  '#d0e11c',
#  '#d0e11c',
#  '#d0e11c',
#  '#cde11d',
#  '#cde11d',
#  '#cde11d',
#  '#cde11d',
#  '#cae11f',
#  '#cae11f',
#  '#cae11f',
#  '#cae11f',
#  '#c8e020',
#  '#c8e020',
#  '#c8e020',
#  '#c5e021',
#  '#c5e021',
#  '#c5e021',
#  '#c5e021',
#  '#c2df23',
#  '#c2df23',
#  '#c2df23',
#  '#c2df23',
#  '#c0df25',
#  '#c0df25',
#  '#c0df25',
#  '#bddf26',
#  '#bddf26',
#  '#bddf26',
#  '#bddf26',
#  '#bade28',
#  '#bade28',
#  '#bade28',
#  '#bade28',
#  '#b8de29',
#  '#b8de29',
#  '#b8de29',
#  '#b8de29',
#  '#b5de2b',
#  '#b5de2b',
#  '#b5de2b',
#  '#b2dd2d',
#  '#b2dd2d',
#  '#b2dd2d',
#  '#b2dd2d',
#  '#b0dd2f',
#  '#b0dd2f',
#  '#b0dd2f',
#  '#b0dd2f',
#  '#addc30',
#  '#addc30',
#  '#addc30',
#  '#aadc32',
#  '#aadc32',
#  '#aadc32',
#  '#aadc32',
#  '#a8db34',
#  '#a8db34',
#  '#a8db34',
#  '#a8db34',
#  '#a5db36',
#  '#a5db36',
#  '#a5db36',
#  '#a5db36',
#  '#a2da37',
#  '#a2da37',
#  '#a2da37',
#  '#a0da39',
#  '#a0da39',
#  '#a0da39',
#  '#a0da39',
#  '#9dd93b',
#  '#9dd93b',
#  '#9dd93b',
#  '#9dd93b',
#  '#9bd93c',
#  '#9bd93c',
#  '#9bd93c',
#  '#98d83e',
#  '#98d83e',
#  '#98d83e',
#  '#98d83e',
#  '#95d840',
#  '#95d840',
#  '#95d840',
#  '#95d840',
#  '#93d741',
#  '#93d741',
#  '#93d741',
#  '#93d741',
#  '#90d743',
#  '#90d743',
#  '#90d743',
#  '#8ed645',
#  '#8ed645',
#  '#8ed645',
#  '#8ed645',
#  '#8bd646',
#  '#8bd646',
#  '#8bd646',
#  '#8bd646',
#  '#89d548',
#  '#89d548',
#  '#89d548',
#  '#86d549',
#  '#86d549',
#  '#86d549',
#  '#86d549',
#  '#84d44b',
#  '#84d44b',
#  '#84d44b',
#  '#84d44b',
#  '#81d34d',
#  '#81d34d',
#  '#81d34d',
#  '#81d34d',
#  '#7fd34e',
#  '#7fd34e',
#  '#7fd34e',
#  '#7cd250',
#  '#7cd250',
#  '#7cd250',
#  '#7cd250',
#  '#7ad151',
#  '#7ad151',
#  '#7ad151',
#  '#7ad151',
#  '#77d153',
#  '#77d153',
#  '#77d153',
#  '#75d054',
#  '#75d054',
#  '#75d054',
#  '#75d054',
#  '#73d056',
#  '#73d056',
#  '#73d056',
#  '#73d056',
#  '#70cf57',
#  '#70cf57',
#  '#70cf57',
#  '#70cf57',
#  '#6ece58',
#  '#6ece58',
#  '#6ece58',
#  '#6ccd5a',
#  '#6ccd5a',
#  '#6ccd5a',
#  '#6ccd5a',
#  '#69cd5b',
#  '#69cd5b',
#  '#69cd5b',
#  '#69cd5b',
#  '#67cc5c',
#  '#67cc5c',
#  '#67cc5c',
#  '#65cb5e',
#  '#65cb5e',
#  '#65cb5e',
#  '#65cb5e',
#  '#63cb5f',
#  '#63cb5f',
#  '#63cb5f',
#  '#63cb5f',
#  '#60ca60',
#  '#60ca60',
#  '#60ca60',
#  '#60ca60',
#  '#5ec962',
#  '#5ec962',
#  '#5ec962',
#  '#5cc863',
#  '#5cc863',
#  '#5cc863',
#  '#5cc863',
#  '#5ac864',
#  '#5ac864',
#  '#5ac864',
#  '#5ac864',
#  '#58c765',
#  '#58c765',
#  '#58c765',
#  '#56c667',
#  '#56c667',
#  '#56c667',
#  '#56c667',
#  '#54c568',
#  '#54c568',
#  '#54c568',
#  '#54c568',
#  '#52c569',
#  '#52c569',
#  '#52c569',
#  '#52c569',
#  '#50c46a',
#  '#50c46a',
#  '#50c46a',
#  '#4ec36b',
#  '#4ec36b',
#  '#4ec36b',
#  '#4ec36b',
#  '#4cc26c',
#  '#4cc26c',
#  '#4cc26c',
#  '#4cc26c',
#  '#4ac16d',
#  '#4ac16d',
#  '#4ac16d',
#  '#48c16e',
#  '#48c16e',
#  '#48c16e',
#  '#48c16e',
#  '#46c06f',
#  '#46c06f',
#  '#46c06f',
#  '#46c06f',
#  '#44bf70',
#  '#44bf70',
#  '#44bf70',
#  '#44bf70',
#  '#42be71',
#  '#42be71',
#  '#42be71',
#  '#40bd72',
#  '#40bd72',
#  '#40bd72',
#  '#40bd72',
#  '#3fbc73',
#  '#3fbc73',
#  '#3fbc73',
#  '#3fbc73',
#  '#3dbc74',
#  '#3dbc74',
#  '#3dbc74',
#  '#3bbb75',
#  '#3bbb75',
#  '#3bbb75',
#  '#3bbb75',
#  '#3aba76',
#  '#3aba76',
#  '#3aba76',
#  '#3aba76',
#  '#38b977',
#  '#38b977',
#  '#38b977',
#  '#38b977',
#  '#37b878',
#  '#37b878',
#  '#37b878',
#  '#35b779',
#  '#35b779',
#  '#35b779',
#  '#35b779',
#  '#34b679',
#  '#34b679',
#  '#34b679',
#  '#34b679',
#  '#32b67a',
#  '#32b67a',
#  '#32b67a',
#  '#31b57b',
#  '#31b57b',
#  '#31b57b',
#  '#31b57b',
#  '#2fb47c',
#  '#2fb47c',
#  '#2fb47c',
#  '#2fb47c',
#  '#2eb37c',
#  '#2eb37c',
#  '#2eb37c',
#  '#2eb37c',
#  '#2db27d',
#  '#2db27d',
#  '#2db27d',
#  '#2cb17e',
#  '#2cb17e',
#  '#2cb17e',
#  '#2cb17e',
#  '#2ab07f',
#  '#2ab07f',
#  '#2ab07f',
#  '#2ab07f',
#  '#29af7f',
#  '#29af7f',
#  '#29af7f',
#  '#28ae80',
#  '#28ae80',
#  '#28ae80',
#  '#28ae80',
#  '#27ad81',
#  '#27ad81',
#  '#27ad81',
#  '#27ad81',
#  '#26ad81',
#  '#26ad81',
#  '#26ad81',
#  '#26ad81',
#  '#25ac82',
#  '#25ac82',
#  '#25ac82',
#  '#25ab82',
#  '#25ab82',
#  '#25ab82',
#  '#25ab82',
#  '#24aa83',
#  '#24aa83',
#  '#24aa83',
#  '#24aa83',
#  '#23a983',
#  '#23a983',
#  '#23a983',
#  '#22a884',
#  '#22a884',
#  '#22a884',
#  '#22a884',
#  '#22a785',
#  '#22a785',
#  '#22a785',
#  '#22a785',
#  '#21a685',
#  '#21a685',
#  '#21a685',
#  '#21a685',
#  '#21a585',
#  '#21a585',
#  '#21a585',
#  '#20a486',
#  '#20a486',
#  '#20a486',
#  '#20a486',
#  '#20a386',
#  '#20a386',
#  '#20a386',
#  '#20a386',
#  '#1fa287',
#  '#1fa287',
#  '#1fa287',
#  '#1fa187',
#  '#1fa187',
#  '#1fa187',
#  '#1fa187',
#  '#1fa188',
#  '#1fa188',
#  '#1fa188',
#  '#1fa188',
#  '#1fa088',
#  '#1fa088',
#  '#1fa088',
#  '#1fa088',
#  '#1f9f88',
#  '#1f9f88',
#  '#1f9f88',
#  '#1f9e89',
#  '#1f9e89',
#  '#1f9e89',
#  '#1f9e89',
#  '#1e9d89',
#  '#1e9d89',
#  '#1e9d89',
#  '#1e9d89',
#  '#1e9c89',
#  '#1e9c89',
#  '#1e9c89',
#  '#1e9b8a',
#  '#1e9b8a',
#  '#1e9b8a',
#  '#1e9b8a',
#  '#1f9a8a',
#  '#1f9a8a',
#  '#1f9a8a',
#  '#1f9a8a',
#  '#1f998a',
#  '#1f998a',
#  '#1f998a',
#  '#1f998a',
#  '#1f988b',
#  '#1f988b',
#  '#1f988b',
#  '#1f978b',
#  '#1f978b',
#  '#1f978b',
#  '#1f978b',
#  '#1f968b',
#  '#1f968b',
#  '#1f968b',
#  '#1f968b',
#  '#1f958b',
#  '#1f958b',
#  '#1f958b',
#  '#1f948c',
#  '#1f948c',
#  '#1f948c',
#  '#1f948c',
#  '#20938c',
#  '#20938c',
#  '#20938c',
#  '#20938c',
#  '#20928c',
#  '#20928c',
#  '#20928c',
#  '#20928c',
#  '#20928c',
#  '#20928c',
#  '#20928c',
#  '#21918c',
#  '#21918c',
#  '#21918c',
#  '#21918c',
#  '#21908d',
#  '#21908d',
#  '#21908d',
#  '#21908d',
#  '#218f8d',
#  '#218f8d',
#  '#218f8d',
#  '#218e8d',
#  '#218e8d',
#  '#218e8d',
#  '#218e8d',
#  '#228d8d',
#  '#228d8d',
#  '#228d8d',
#  '#228d8d',
#  '#228c8d',
#  '#228c8d',
#  '#228c8d',
#  '#228c8d',
#  '#228b8d',
#  '#228b8d',
#  '#228b8d',
#  '#238a8d',
#  '#238a8d',
#  '#238a8d',
#  '#238a8d',
#  '#23898e',
#  '#23898e',
#  '#23898e',
#  '#23898e',
#  '#23888e',
#  '#23888e',
#  '#23888e',
#  '#24878e',
#  '#24878e',
#  '#24878e',
#  '#24878e',
#  '#24868e',
#  '#24868e',
#  '#24868e',
#  '#24868e',
#  '#25858e',
#  '#25858e',
#  '#25858e',
#  '#25858e',
#  '#25848e',
#  '#25848e',
#  '#25848e',
#  '#25838e',
#  '#25838e',
#  '#25838e',
#  '#25838e',
#  '#26828e',
#  '#26828e',
#  '#26828e',
#  '#26828e',
#  '#26828e',
#  '#26828e',
#  '#26828e',
#  '#26818e',
#  '#26818e',
#  '#26818e',
#  '#26818e',
#  '#27808e',
#  '#27808e',
#  '#27808e',
#  '#27808e',
#  '#277f8e',
#  '#277f8e',
#  '#277f8e',
#  '#277f8e',
#  '#277e8e',
#  '#277e8e',
#  '#277e8e',
#  '#287d8e',
#  '#287d8e',
#  '#287d8e',
#  '#287d8e',
#  '#287c8e',
#  '#287c8e',
#  '#287c8e',
#  '#287c8e',
#  '#297b8e',
#  '#297b8e',
#  '#297b8e',
#  '#297a8e',
#  '#297a8e',
#  '#297a8e',
#  '#297a8e',
#  '#29798e',
#  '#29798e',
#  '#29798e',
#  '#29798e',
#  '#2a788e',
#  '#2a788e',
#  '#2a788e',
#  '#2a788e',
#  '#2a778e',
#  '#2a778e',
#  '#2a778e',
#  '#2a768e',
#  '#2a768e',
#  '#2a768e',
#  '#2a768e',
#  '#2b758e',
#  '#2b758e',
#  '#2b758e',
#  '#2b758e',
#  '#2b748e',
#  '#2b748e',
#  '#2b748e',
#  '#2c738e',
#  '#2c738e',
#  '#2c738e',
#  '#2c738e',
#  '#2c728e',
#  '#2c728e',
#  '#2c728e',
#  '#2c728e',
#  '#2c718e',
#  '#2c718e',
#  '#2c718e',
#  '#2c718e',
#  '#2d718e',
#  '#2d718e',
#  '#2d718e',
#  '#2d708e',
#  '#2d708e',
#  '#2d708e',
#  '#2d708e',
#  '#2e6f8e',
#  '#2e6f8e',
#  '#2e6f8e',
#  '#2e6f8e',
#  '#2e6e8e',
#  '#2e6e8e',
#  '#2e6e8e',
#  '#2e6d8e',
#  '#2e6d8e',
#  '#2e6d8e',
#  '#2e6d8e',
#  '#2f6c8e',
#  '#2f6c8e',
#  '#2f6c8e',
#  '#2f6c8e',
#  '#2f6b8e',
#  '#2f6b8e',
#  '#2f6b8e',
#  '#2f6b8e',
#  '#306a8e',
#  '#306a8e',
#  '#306a8e',
#  '#30698e',
#  '#30698e',
#  '#30698e',
#  '#30698e',
#  '#31688e',
#  '#31688e',
#  '#31688e',
#  '#31688e',
#  '#31678e',
#  '#31678e',
#  '#31678e',
#  '#31668e',
#  '#31668e',
#  '#31668e',
#  '#31668e',
#  '#32658e',
#  '#32658e',
#  '#32658e',
#  '#32658e',
#  '#32648e',
#  '#32648e',
#  '#32648e',
#  '#32648e',
#  '#33638d',
#  '#33638d',
#  '#33638d',
#  '#33628d',
#  '#33628d',
#  '#33628d',
#  '#33628d',
#  '#34618d',
#  '#34618d',
#  '#34618d',
#  '#34618d',
#  '#34608d',
#  '#34608d',
#  '#34608d',
#  '#355f8d',
#  '#355f8d',
#  '#355f8d',
#  '#355f8d',
#  '#355e8d',
#  '#355e8d',
#  '#355e8d',
#  '#355e8d',
#  '#365d8d',
#  '#365d8d',
#  '#365d8d',
#  '#365d8d',
#  '#365c8d',
#  '#365c8d',
#  '#365c8d',
#  '#375b8d',
#  '#375b8d',
#  '#375b8d',
#  '#375b8d',
#  '#375a8c',
#  '#375a8c',
#  '#375a8c',
#  '#375a8c',
#  '#38598c',
#  '#38598c',
#  '#38598c',
#  '#38588c',
#  '#38588c',
#  '#38588c',
#  '#38588c',
#  '#39568c',
#  '#39568c',
#  '#39568c',
#  '#39568c',
#  '#39558c',
#  '#39558c',
#  '#39558c',
#  '#39558c',
#  '#3a548c',
#  '#3a548c',
#  '#3a548c',
#  '#3a538b',
#  '#3a538b',
#  '#3a538b',
#  '#3a538b',
#  '#3b528b',
#  '#3b528b',
#  '#3b528b',
#  '#3b528b',
#  '#3b518b',
#  '#3b518b',
#  '#3b518b',
#  '#3c508b',
#  '#3c508b',
#  '#3c508b',
#  '#3c508b',
#  '#3c4f8a',
#  '#3c4f8a',
#  '#3c4f8a',
#  '#3c4f8a',
#  '#3d4e8a',
#  '#3d4e8a',
#  '#3d4e8a',
#  '#3d4e8a',
#  '#3d4d8a',
#  '#3d4d8a',
#  '#3d4d8a',
#  '#3e4c8a',
#  '#3e4c8a',
#  '#3e4c8a',
#  '#3e4c8a',
#  '#3e4a89',
#  '#3e4a89',
#  '#3e4a89',
#  '#3e4a89',
#  '#3e4989',
#  '#3e4989',
#  '#3e4989',
#  '#3f4889',
#  '#3f4889',
#  '#3f4889',
#  '#3f4889',
#  '#3f4788',
#  '#3f4788',
#  '#3f4788',
#  '#3f4788',
#  '#404688',
#  '#404688',
#  '#404688',
#  '#404688',
#  '#404588',
#  '#404588',
#  '#404588',
#  '#414487',
#  '#414487',
#  '#414487',
#  '#414487',
#  '#414287',
#  '#414287',
#  '#414287',
#  '#414287',
#  '#424186',
#  '#424186',
#  '#424186',
#  '#424086',
#  '#424086',
#  '#424086',
#  '#424086',
#  '#423f85',
#  '#423f85',
#  '#423f85',
#  '#423f85',
#  '#433e85',
#  '#433e85',
#  '#433e85',
#  '#433e85',
#  '#433d84',
#  '#433d84',
#  '#433d84',
#  '#443b84',
#  '#443b84',
#  '#443b84',
#  '#443b84',
#  '#443a83',
#  '#443a83',
#  '#443a83',
#  '#443a83',
#  '#443983',
#  '#443983',
#  '#443983',
#  '#453882',
#  '#453882',
#  '#453882',
#  '#453882',
#  '#453781',
#  '#453781',
#  '#453781',
#  '#453781',
#  '#453581',
#  '#453581',
#  '#453581',
#  '#453581',
#  '#463480',
#  '#463480',
#  '#463480',
#  '#46337f',
#  '#46337f',
#  '#46337f',
#  '#46337f',
#  '#46327e',
#  '#46327e',
#  '#46327e',
#  '#46327e',
#  '#46307e',
#  '#46307e',
#  '#46307e',
#  '#472f7d',
#  '#472f7d',
#  '#472f7d',
#  '#472f7d',
#  '#472e7c',
#  '#472e7c',
#  '#472e7c',
#  '#472e7c',
#  '#472d7b',
#  '#472d7b',
#  '#472d7b',
#  '#472d7b',
#  '#472c7a',
#  '#472c7a',
#  '#472c7a',
#  '#472a7a',
#  '#472a7a',
#  '#472a7a',
#  '#472a7a',
#  '#482979',
#  '#482979',
#  '#482979',
#  '#482979',
#  '#482878',
#  '#482878',
#  '#482878',
#  '#482677',
#  '#482677',
#  '#482677',
#  '#482677',
#  '#482576',
#  '#482576',
#  '#482576',
#  '#482576',
#  '#482475',
#  '#482475',
#  '#482475',
#  '#482475',
#  '#482374',
#  '#482374',
#  '#482374',
#  '#482173',
#  '#482173',
#  '#482173',
#  '#482173',
#  '#482071',
#  '#482071',
#  '#482071',
#  '#482071',
#  '#481f70',
#  '#481f70',
#  '#481f70',
#  '#481d6f',
#  '#481d6f',
#  '#481d6f',
#  '#481d6f',
#  '#481c6e',
#  '#481c6e',
#  '#481c6e',
#  '#481c6e',
#  '#481b6d',
#  '#481b6d',
#  '#481b6d',
#  '#481b6d',
#  '#481a6c',
#  '#481a6c',
#  '#481a6c',
#  '#48186a',
#  '#48186a',
#  '#48186a',
#  '#48186a',
#  '#481769',
#  '#481769',
#  '#481769',
#  '#481769',
#  '#481668',
#  '#481668',
#  '#481668',
#  '#481467',
#  '#481467',
#  '#481467',
#  '#481467',
#  '#471365',
#  '#471365',
#  '#471365',
#  '#471365',
#  '#471164',
#  '#471164',
#  '#471164',
#  '#471164',
#  '#471063',
#  '#471063',
#  '#471063',
#  '#470e61',
#  '#470e61',
#  '#470e61',
#  '#470e61',
#  '#470d60',
#  '#470d60',
#  '#470d60',
#  '#470d60',
#  '#460b5e',
#  '#460b5e',
#  '#460b5e',
#  '#460a5d',
#  '#460a5d',
#  '#460a5d',
#  '#460a5d',
#  '#46085c',
#  '#46085c',
#  '#46085c',
#  '#46085c',
#  '#46075a',
#  '#46075a',
#  '#46075a',
#  '#46075a',
#  '#450559',
#  '#450559',
#  '#450559',
#  '#450457',
#  '#450457',
#  '#450457',
#  '#450457',
#  '#440256',
#  '#440256',
#  '#440256',
#  '#440256',
#  '#440154',
#  '#440154',
#  '#440154']

# %%
Teams_matches
# Out:
#                           Teams  Total_matches
# 0                Mumbai Indians            231
# 1   Royal Challengers Bangalore            226
# 2                Delhi Capitals            224
# 3         Kolkata Knight Riders            223
# 4                  Punjab Kings            218
# 5           Chennai Super Kings            208
# 6              Rajasthan Royals            192
# 7           Sunrisers Hyderabad            152
# 8               Deccan Chargers             75
# 9                 Pune Warriors             46
# 10       Rising Pune Supergiant             30
# 11                Gujarat Lions             30
# 12               Gujarat Titans             16
# 13         Lucknow Super Giants             15
# 14         Kochi Tuskers Kerala             14

# %%
# Set figure size
plt.figure(figsize=(30, 10))

# Create bar plot
Teams_matches1 = Teams_matches.head(10)
bars = plt.bar(
    Teams_matches1['Teams'],
    Teams_matches1['Total_matches'],
    color=pal_vi[:len(Teams_matches1)]  # Use your color palette
)


plt.xlabel('Teams')
plt.ylabel('Total Matches')
for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        height,
        f'{height}',
        ha='center',
        va='bottom',
        fontsize=10
    )

# %%
# Customize plot appearance
plt.xlabel('Teams')
plt.ylabel('Total matches')
plt.xticks(rotation=45)
plt.gca().set_facecolor('white')   # Plot background
plt.gcf().set_facecolor('white')   # Figure background

# Remove top and right spines for a cleaner look
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
team_mapping = {
    'Mumbai Indians': 'MI',
    'Royal Challengers Bangalore': 'RCB',
    'Delhi Capitals': 'DC',
    'Kolkata Knight Riders': 'KKR',
    'Punjab Kings': 'PBKS',
    'Chennai Super Kings': 'CSK',
    'Rajasthan Royals': 'RR',
    'Sunrisers Hyderabad': 'SRH',
    'Deccan Chargers': 'DCG',
    'Pune Warriors': 'PW',
    'Rising Pune Supergiant': 'RPS',
    'Gujarat Lions': 'GL',
    'Gujarat Titans': 'GT',
    'Lucknow Super Giants': 'LSG',
    'Kochi Tuskers Kerala': 'KTK'
}

Teams_matches.replace(team_mapping, inplace=True)

# %%
sns.set(rc={'figure.figsize':(20,10)})
ax= sns.barplot(Teams_matches,x='Teams',y='Total_matches')
for bar in ax.containers:
    ax.bar_label(bar)

# %%
ax= sns.barplot(Teams_matches,x='Teams',y='Total_matches')
for bar in ax.containers:
    ax.bar_label(bar)
plt.show()

# %%
pip install plotly --upgrade --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script plotly_get_chrome.exe is installed in 'C:\Users\klemp\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
Teams_matches
# Out:
#    Teams  Total_matches
# 0     MI            231
# 1    RCB            226
# 2     DC            224
# 3    KKR            223
# 4   PBKS            218
# 5    CSK            208
# 6     RR            192
# 7    SRH            152
# 8    DCG             75
# 9     PW             46
# 10   RPS             30
# 11    GL             30
# 12    GT             16
# 13   LSG             15
# 14   KTK             14

# %%
   
import plotly.express as px
fig = px.bar(Teams_matches, x='Teams', y='Total_matches', text='Total_matches',
             color ='Teams', color_discrete_sequence=pal_vi)

fig.update_traces(texttemplate='%{text:.3s}', textposition='outside')
fig.update_layout({'plot_bgcolor': 'white',
                   'paper_bgcolor': 'white'})

fig.update_layout(width=1100, height=500,
                  margin = dict(t=15, l=15, r=15, b=15))
fig.show()

# %% [markdown]
# By above analysis we can see that number of matches played by Mumbai indians, Royal Challengers Bangalore, Delhi Capitals, Kolkata Knight Riders, Punjab Kings, Chennai Super Kings is high. On the other hand, Kings, Kochi Tuskers Kerala, Pune Warriors, Gujarat Lions,deccan Rising Pune Supergiant are the defunct team by BCCI.

# %% [markdown]
# ## Winning Ratio Analysis

# %%
Teams_matches.drop(columns=['total_wins'],inplace = True)

# %%
Teams_matches
# Out:
#    Teams  Total_matches
# 0     MI            231
# 1    RCB            226
# 2     DC            224
# 3    KKR            223
# 4   PBKS            218
# 5    CSK            208
# 6     RR            192
# 7    SRH            152
# 8    DCG             75
# 9     PW             46
# 10   RPS             30
# 11    GL             30
# 12    GT             16
# 13   LSG             15
# 14   KTK             14

# %%
win_df = Teams_matches
win_df['total_wins']=df['WinningTeam'].value_counts().reset_index()['count']
win_df['win_ratio']= round((win_df['total_wins']/win_df['Total_matches']),2)*100
win_df
# Out:
#    Teams  Total_matches  total_wins  Total_wins  win_ratio
# 0     MI            231         131         131       57.0
# 1    RCB            226         121         121       54.0
# 2     DC            224         114         114       51.0
# 3    KKR            223         109         109       49.0
# 4   PBKS            218         103         103       47.0
# 5    CSK            208         101         101       49.0
# 6     RR            192          96          96       50.0
# 7    SRH            152          75          75       49.0
# 8    DCG             75          29          29       39.0
# 9     PW             46          15          15       33.0
# 10   RPS             30          13          13       43.0
# 11    GL             30          12          12       40.0
# 12    GT             16          12          12       75.0
# 13   LSG             15           9           9       60.0
# 14   KTK             14           6           6       43.0

# %%
Teams_matches.drop(columns=['total_wins'])

# %%
win_df = match_df
win_df['total_wins']=IPL_matches_df['WinningTeam'].value_counts().reset_index()['WinningTeam']

# %%
df['WinningTeam'].value_counts()
# Out:
# WinningTeam
# Mumbai Indians                 131
# Chennai Super Kings            121
# Kolkata Knight Riders          114
# Royal Challengers Bangalore    109
# Delhi Capitals                 103
# Punjab Kings                   101
# Rajasthan Royals                96
# Sunrisers Hyderabad             75
# Deccan Chargers                 29
# Rising Pune Supergiant          15
# Gujarat Lions                   13
# Gujarat Titans                  12
# Pune Warriors                   12
# Lucknow Super Giants             9
# Kochi Tuskers Kerala             6
# NoResult                         4
# Name: count, dtype: int64

# %%
win_df=Teams_matches

# %%
win_df['total_wins']=df['WinningTeam'].value_counts().reset_index()['WinningTeam']

# %%
df['WinningTeam'].value_counts().reset_index()
# Out:
#                     WinningTeam  count
# 0                Mumbai Indians    131
# 1           Chennai Super Kings    121
# 2         Kolkata Knight Riders    114
# 3   Royal Challengers Bangalore    109
# 4                Delhi Capitals    103
# 5                  Punjab Kings    101
# 6              Rajasthan Royals     96
# 7           Sunrisers Hyderabad     75
# 8               Deccan Chargers     29
# 9        Rising Pune Supergiant     15
# 10                Gujarat Lions     13
# 11               Gujarat Titans     12
# 12                Pune Warriors     12
# 13         Lucknow Super Giants      9
# 14         Kochi Tuskers Kerala      6
# 15                     NoResult      4

# %%
df['WinningTeam'].value_counts().reset_index()['WinningTeam']
# Out:
# 0                  Mumbai Indians
# 1             Chennai Super Kings
# 2           Kolkata Knight Riders
# 3     Royal Challengers Bangalore
# 4                  Delhi Capitals
# 5                    Punjab Kings
# 6                Rajasthan Royals
# 7             Sunrisers Hyderabad
# 8                 Deccan Chargers
# 9          Rising Pune Supergiant
# 10                  Gujarat Lions
# 11                 Gujarat Titans
# 12                  Pune Warriors
# 13           Lucknow Super Giants
# 14           Kochi Tuskers Kerala
# 15                       NoResult
# Name: WinningTeam, dtype: object

# %%
win_df['win_ratio'].sort_values()

# %%
plt.figure(figsize=(15,6.5))
sns.set_style('darkgrid')
wi = sns.barplot(data=win_df, x='win_ratio', y='Teams', ci=False)
wi.set_xticklabels(win_df['win_ratio'].sort_values(), rotation=90, fontdict={'fontsize':10})
plt.show()

# %% [markdown]
# we can see that Gujrat Titans has best winning percentage but Gujrat Titans has low number of matches played. So, overall Mumbai Indians has good winning percentage.

# %% [markdown]
# ## Top 10 Batters that got Player of Match Title

# %%
df['Player_of_Match'].value_counts().reset_index()
# Out:
#     Player_of_Match  count
# 0    AB de Villiers     25
# 1          CH Gayle     22
# 2         RG Sharma     18
# 3         DA Warner     18
# 4          MS Dhoni     17
# ..              ...    ...
# 258     SA Asnodkar      1
# 259      GD McGrath      1
# 260       SM Katich      1
# 261        JDP Oram      1
# 262     MF Maharoof      1
#
# [263 rows x 2 columns]

# %%
df['Player_of_Match'].value_counts().reset_index()
# Out:
#     Player_of_Match  count
# 0    AB de Villiers     25
# 1          CH Gayle     22
# 2         RG Sharma     18
# 3         DA Warner     18
# 4          MS Dhoni     17
# ..              ...    ...
# 258     SA Asnodkar      1
# 259      GD McGrath      1
# 260       SM Katich      1
# 261        JDP Oram      1
# 262     MF Maharoof      1
#
# [263 rows x 2 columns]

# %%
Player_of_Match_df = df['Player_of_Match'].value_counts().reset_index()
top_10_Player_of_Match = Player_of_Match_df.head(10)

# %%
plt.figure(figsize=(9,4))
plt.plot(top_10_Player_of_match['count'], top_10_Player_of_Match['Player_of_Match'], 'o-g')

plt.xlabel('Count')
plt.ylabel('Player of Match')

plt.title('Top 10 Player of Match');
plt.show()

# %% [markdown]
# Above analysis show that, with 25 man of the match trophies, **AB de Villiers** has most man of the match in IPL. While **CH Gayle** is in second number who has most man of the match in IPL.

# %% [markdown]
# ## Top 10 IPL hosted cities
# We will analyze the top cities that hosted IPL most time.

# %%
citraw = df['City'].value_counts().reset_index()

# %%
citraw
# Out:
#               City  count
# 0           Mumbai    159
# 1        Bangalore     80
# 2          Kolkata     79
# 3            Delhi     78
# 4          Chennai     67
# 5        Hyderabad     64
# 6       Chandigarh     56
# 7             Pune     51
# 8           Jaipur     47
# 9        Abu Dhabi     37
# 10       Ahmedabad     19
# 11          Durban     15
# 12   Visakhapatnam     13
# 13           Dubai     13
# 14       Centurion     12
# 15         Sharjah     10
# 16          Rajkot     10
# 17     Navi Mumbai      9
# 18          Indore      9
# 19      Dharamsala      9
# 20    Johannesburg      8
# 21  Port Elizabeth      7
# 22         Cuttack      7
# 23          Ranchi      7
# 24       Cape Town      7
# 25          Raipur      6
# 26           Kochi      5
# 27          Kanpur      4
# 28          Nagpur      3
# 29       Kimberley      3
# 30     East London      3
# 31    Bloemfontein      2

# %%
citraw = df['City'].value_counts().reset_index()
citraw.set_axis(['City','Hosted_Number'],axis = 'columns' )
top10_city_host = citraw.head(10)
top10_city_host
# Out:
#          City  count
# 0      Mumbai    159
# 1   Bangalore     80
# 2     Kolkata     79
# 3       Delhi     78
# 4     Chennai     67
# 5   Hyderabad     64
# 6  Chandigarh     56
# 7        Pune     51
# 8      Jaipur     47
# 9   Abu Dhabi     37

# %%
plt.figure(figsize=(16,8))
palette_color = sns.color_palette("ch:s=.25,rot=-.25")
sns.barplot(x='count', y='City',palette = palette_color, data=top10_city_host);
plt.title('Top 10 IPL hosted cities');
plt.show()

# %% [markdown]
# Mumbai hosted maximum matches of Indian Premium League.

# %% [markdown]
# ## Number of Matches hosted in Seasons

# %%
pd.DatetimeIndex(df["Date"]).year
# Out:
# Index([2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022,
#        ...
#        2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008],
#       dtype='int32', name='Date', length=950)

# %%
IPL_matches_df["Season"]=pd.DatetimeIndex(IPL_matches_df["Date"]).year
matches_in_season=IPL_matches_df.groupby(['Season'])['ID'].count().reset_index().rename(columns={'ID':'matches'})
matches_in_season
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[412], line 1
# ----> 1 IPL_matches_df["Season"]=pd.DatetimeIndex(IPL_matches_df["Date"]).year
#       2 matches_in_season=IPL_matches_df.groupby(['Season'])['ID'].count().reset_index().rename(columns={'ID':'matches'})
#       3 matches_in_season
#
# NameError: name 'IPL_matches_df' is not defined

# %%
plt.figure(figsize=(12,5))

sns.barplot(x='Season', y='matches', data=matches_in_season);
plt.title('No of total matches per season');
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[295], line 3
#       1 plt.figure(figsize=(12,5))
# ----> 3 sns.barplot(x='Season', y='matches', data=matches_in_season);
#       4 plt.title('No of total matches per season');
#       5 plt.show()
#
# NameError: name 'matches_in_season' is not defined

# %% [markdown]
# There is chart that show total number of matches held in each Season of IPL. In 2011,2012,2013 and 2022 IPL number of total matches greater than other seasons.

# %% [markdown]
# ## Most Time Toss Winning Teams

# %%
most_toss_winner = df['TossWinner'].value_counts().reset_index()
most_toss_winner.set_axis(['TossWinner','Count'],axis = 'columns' ,inplace = True)
most_toss_winner
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[308], line 2
#       1 most_toss_winner = df['TossWinner'].value_counts().reset_index()
# ----> 2 most_toss_winner.set_axis(['TossWinner','Count'],axis = 'columns' ,inplace = True)
#       3 most_toss_winner
#
# TypeError: DataFrame.set_axis() got an unexpected keyword argument 'inplace'

# %%
plt.figure(figsize=(16,12))
plt.plot(most_toss_winner['count'], most_toss_winner['TossWinner'], marker='s', c='r', ls='--', lw=2, ms=10, mew=2, mec='navy')

plt.xlabel('Toss Winner')
plt.ylabel('Count')

plt.title('Most time toss winning teams')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[306], line 2
#       1 plt.figure(figsize=(16,12))
# ----> 2 plt.plot(most_toss_winner['count'], most_toss_winner['TossWinner'], marker='s', c='r', ls='--', lw=2, ms=10, mew=2, mec='navy')
#       4 plt.xlabel('Toss Winner')
#       5 plt.ylabel('Count')
#
# NameError: name 'most_toss_winner' is not defined

# %% [markdown]
# Toss is the most important thing in the cricket, winning the toss has also impact on match win, we will analyze it later. First we can see that **Mumbai Indians**, **Kolkata Knight Riders** and **Chennai Super Kings** won toss most time in IPL history.

# %% [markdown]
# ## Toss Decision in each Season of IPL

# %%
plt.figure(figsize=(16,6))
color_palette = sns.color_palette("Spectral")
sns.countplot(x='Season', hue='TossDecision', data=IPL_matches_df,palette=color_palette,saturation=1)
plt.title('Toss Decision in each Season of IPL');

# %% [markdown]
# In 2016, 2017, 2018, and 2019 most of the teams were field first after winning the toss. But the data show that, in 2020 teams went for bat first after winning toss because in 2020 IPL was held in Dubai, and Dubai stadium's ground and weather conditions suit for bat first. After 2020, in 2021 and 2022 teams again chose the field first after winning toss because IPL held again in INDIA.
